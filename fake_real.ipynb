# %%
import csv
from nltk.classify import SklearnClassifier
from random import shuffle
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
import numpy as np
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams
import string

# %%
def load(name):
    with open(name) as f:
        read = csv.reader(f, delimiter='\t')
        next(read)
        for line in read:
            (ID, Text, Label) = convert1(line)
            rawData.append((ID, Text, Label))
            preprocessedData.append((ID, preProcess(Text), Label))

# %%
def splitting(ratio):
    samples=len(rawData)
    half= int(len(rawData)/2)
    trainingSamples = int((ratio*samples)/2)
    for (_, Text, Label) in rawData[:trainingSamples] + rawData[half:half+trainingSamples]:
        trainData.append((toFeatureVector(preProcess(Text)),Label))
    for (_, Text, Label) in rawData[trainingSamples:half] + rawData[half+trainingSamples:]:
        testData.append((toFeatureVector(preProcess(Text)),Label))

# %%
def convert1(reviewLine):
    s=""
    if reviewLine[1]=="__label1__":
        s = "fake"
    else: 
        s = "real"
    return (reviewLine[0], reviewLine[8], s)

# %%
table=str.maketrans({key: None for key in string.punctuation})
def preProcess(text):
    lemmatizer = WordNetLemmatizer()
    filtered_tokens=[]
    lemmatized_tokens = []
    stop_words = set(stopwords.words('english'))
    text = text.translate(table)
    for w in text.split(" "):
        if w not in stop_words:
            lemmatized_tokens.append(lemmatizer.lemmatize(w.lower()))
        filtered_tokens = [' '.join(l) for l in nltk.bigrams(lemmatized_tokens)] + lemmatized_tokens
    return filtered_tokens

# %%
featureDict = {}
def toFeatureVector(tokens):
    localDict = {}
    for token in tokens:
        if token not in featureDict:
            featureDict[token] = 1
        else:
            featureDict[token] = +1
   
        if token not in localDict:
            localDict[token] = 1
        else:
            localDict[token] = +1
    return localDict

# %%
def trainClassifier(trainData):
    pipeline =  Pipeline([('svc', LinearSVC(C=0.01))])
    return SklearnClassifier(pipeline).train(trainData)

# %%
def crossValidate(dataset, folds):
    shuffle(dataset)
    cv_results = []
    foldSize = int(len(dataset)/folds)
    for i in range(0,len(dataset),foldSize):
        classifier = trainClassifier(dataset[:i]+dataset[foldSize+i:])
        y_pred = predictLabels(dataset[i:i+foldSize],classifier)
        a = accuracy_score(list(map(lambda d : d[1], dataset[i:i+foldSize])), y_pred)
        (p,r,f,_) = precision_recall_fscore_support(list(map(lambda d : d[1], dataset[i:i+foldSize])), y_pred, average ='macro')
        cv_results.append((a,p,r,f))
    cv_results = (np.mean(np.array(cv_results),axis=0))
    return cv_results

# %%
def predictLabels(reviewSamples, classifier):
    return classifier.classify_many(map(lambda t: t[0], reviewSamples))

def predictLabel(reviewSample, classifier):
    return classifier.classify(toFeatureVector(preProcess(reviewSample)))

# %%
rawData = []          
preprocessedData = [] 
trainData = []      
testData = [] 
fakeLabel='fake'
realLabel='real'

# %%
name='amazon_reviews1.txt'

# %%
load(name)

# %%
splitting(0.8)

# %%
from sklearn.svm import LinearSVC

# %%
trainData
# Out:
# [({'i received': 1,
#    'received battery': 1,
#    'battery day': 1,
#    'day charged': 1,
#    'charged i': 1,
#    'i tested': 2,
#    'tested flashlight': 1,
#    'flashlight hold': 1,
#    'hold charge': 1,
#    'charge expected': 1,
#    'expected i': 1,
#    'tested millimeter': 1,
#    'millimeter charge': 1,
#    'charge quality': 1,
#    'quality i': 1,
#    'i hoped': 1,
#    'hoped i': 1,
#    'i glad': 1,
#    'glad i': 1,
#    'i purchased': 1,
#    'purchased battery': 1,
#    'battery purchase': 1,
#    'purchase soon': 1,
#    'i': 6,
#    'received': 1,
#    'battery': 2,
#    'day': 1,
#    'charged': 1,
#    'tested': 2,
#    'flashlight': 1,
#    'hold': 1,
#    'charge': 2,
#    'expected': 1,
#    'millimeter': 1,
#    'quality': 1,
#    'hoped': 1,
#    'glad': 1,
#    'purchased': 1,
#    'purchase': 1,
#    'soon': 1},
#   'fake'),
#  ({'it seems': 1,
#    'seems holding': 1,
#    'holding really': 1,
#    'really well': 1,
#    'well husband': 1,
#    'husband boot': 1,
#    'boot ': 1,
#    ' it': 1,
#    'it make': 1,
#    'make look': 1,
#    'look like': 2,
#    'like muddy': 1,
#    'muddy look': 1,
#    'like truck': 1,
#    'truck bedliner': 1,
#    'bedliner i': 1,
#    'i would': 1,
#    'would prefered': 1,
#    'prefered use': 1,
#    'use past': 1,
#    'past seven': 1,
#    'seven day': 1,
#    'day opening': 1,
#    'opening ': 1,
#    ' other': 1,
#    'other awesome': 1,
#    'it': 2,
#    'seems': 1,
#    'holding': 1,
#    'really': 1,
#    'well': 1,
#    'husband': 1,
#    'boot': 1,
#    '': 2,
#    'make': 1,
#    'look': 2,
#    'like': 2,
#    'muddy': 1,
#    'truck': 1,
#    'bedliner': 1,
#    'i': 1,
#    'would': 1,
#    'prefered': 1,
#    'use': 1,
#    'past': 1,
#    'seven': 1,
#    'day': 1,
#    'opening': 1,
#    'other': 1,
#    'awesome': 1},
#   'fake'),
#  ({'a far': 1,
#    'far staple': 1,
#    'staple go': 1,
#    'go excellent': 1,
#    'excellent term': 1,
#    'term quality': 1,
#    'quality performance': 1,
#    'performance i': 1,
#    'i got': 1,
#    'got tired': 1,
#    'tired staple': 1,
#    'staple bend': 1,
#    'bend whenever': 1,
#    'whenever i': 1,
#    'i need': 1,
#    'need punch': 1,
#    'punch thick': 1,
#    'thick stack': 1,
#    'stack go': 1,
#    'go like': 1,
#    'like werent': 1,
#    'werent even': 1,
#    'a': 1,
#    'far': 1,
#    'staple': 2,
#    'go': 2,
#    'excellent': 1,
#    'term': 1,
#    'quality': 1,
#    'performance': 1,
#    'i': 2,
#    'got': 1,
#    'tired': 1,
#    'bend': 1,
#    'whenever': 1,
#    'need': 1,
#    'punch': 1,
#    'thick': 1,
#    'stack': 1,
#    'like': 1,
#    'werent': 1,
#    'even': 1},
#   'fake'),
#  ({'great rubber': 1,
#    'rubber covering': 1,
#    'covering dumbbell': 1,
#    'dumbbell little': 1,
#    'little rough': 1,
#    'rough uncomfortable': 1,
#    'uncomfortable hold': 1,
#    'hold stand': 1,
#    'stand sturdy': 1,
#    'sturdy pretty': 1,
#    'pretty useless': 1,
#    'useless well': 1,
#    'great': 1,
#    'rubber': 1,
#    'covering': 1,
#    'dumbbell': 1,
#    'little': 1,
#    'rough': 1,
#    'uncomfortable': 1,
#    'hold': 1,
#    'stand': 1,
#    'sturdy': 1,
#    'pretty': 1,
#    'useless': 1,
#    'well': 1},
#   'fake'),
#  ({'well great': 1,
#    'great deal': 1,
#    'deal i': 1,
#    'i satisfied': 1,
#    'satisfied i': 1,
#    'i dont': 1,
#    'dont issue': 1,
#    'issue using': 1,
#    'using i': 1,
#    'i buy': 1,
#    'buy another': 1,
#    'another one': 1,
#    'one granny': 1,
#    'well': 1,
#    'great': 1,
#    'deal': 1,
#    'i': 3,
#    'satisfied': 1,
#    'dont': 1,
#    'issue': 1,
#    'using': 1,
#    'buy': 1,
#    'another': 1,
#    'one': 1,
#    'granny': 1},
#   'fake'),
#  ({'i purchased': 1,
#    'purchased product': 1,
#    'product month': 1,
#    'month ago': 1,
#    'ago loved': 1,
#    'loved result': 1,
#    'result i': 1,
#    'i highly': 1,
#    'highly recommend': 1,
#    'recommend anyone': 1,
#    'anyone interested': 1,
#    'interested suppressing': 1,
#    'suppressing appetite': 1,
#    'appetite losing': 1,
#    'losing weight': 1,
#    'i': 2,
#    'purchased': 1,
#    'product': 1,
#    'month': 1,
#    'ago': 1,
#    'loved': 1,
#    'result': 1,
#    'highly': 1,
#    'recommend': 1,
#    'anyone': 1,
#    'interested': 1,
#    'suppressing': 1,
#    'appetite': 1,
#    'losing': 1,
#    'weight': 1},
#   'fake'),
#  ({'do waste': 1,
#    'waste money': 1,
#    'money catsuit': 1,
#    'catsuit since': 1,
#    'since get': 1,
#    'get paid': 1,
#    'paid the': 1,
#    'the suit': 1,
#    'suit made': 1,
#    'made plastic': 1,
#    'plastic like': 1,
#    'like material': 1,
#    'material no': 1,
#    'no stretch': 1,
#    'stretch this': 1,
#    'this look': 1,
#    'look nothing': 1,
#    'nothing like': 1,
#    'like photo': 1,
#    'photo save': 1,
#    'save time': 1,
#    'time money': 1,
#    'do': 1,
#    'waste': 1,
#    'money': 2,
#    'catsuit': 1,
#    'since': 1,
#    'get': 1,
#    'paid': 1,
#    'the': 1,
#    'suit': 1,
#    'made': 1,
#    'plastic': 1,
#    'like': 2,
#    'material': 1,
#    'no': 1,
#    'stretch': 1,
#    'this': 1,
#    'look': 1,
#    'nothing': 1,
#    'photo': 1,
#    'save': 1,
#    'time': 1},
#   'fake'),
#  ({'the shade': 1,
#    'shade size': 1,
#    'size i': 1,
#    'i intended': 1,
#    'intended i': 1,
#    'i see': 1,
#    'see pleated': 1,
#    'pleated shade': 1,
#    'shade fit': 1,
#    'fit standard': 1,
#    'standard size': 1,
#    'size light': 1,
#    'light bulb': 1,
#    'the': 1,
#    'shade': 2,
#    'size': 2,
#    'i': 2,
#    'intended': 1,
#    'see': 1,
#    'pleated': 1,
#    'fit': 1,
#    'standard': 1,
#    'light': 1,
#    'bulb': 1},
#   'fake'),
#  ({'i ordered': 1,
#    'ordered two': 1,
#    'two use': 1,
#    'use nightstands': 1,
#    'nightstands guestroom': 1,
#    'guestroom the': 1,
#    'the hole': 1,
#    'hole didnt': 1,
#    'didnt match': 1,
#    'match i': 1,
#    'i dont': 1,
#    'dont know': 1,
#    'know beginner': 1,
#    'beginner would': 1,
#    'would able': 1,
#    'able fix': 1,
#    'fix problem': 1,
#    'problem thank': 1,
#    'thank goodness': 1,
#    'goodness husband': 1,
#    'husband able': 1,
#    'able drill': 1,
#    'drill new': 1,
#    'new hole': 1,
#    'hole work': 1,
#    'work around': 1,
#    'i': 2,
#    'ordered': 1,
#    'two': 1,
#    'use': 1,
#    'nightstands': 1,
#    'guestroom': 1,
#    'the': 1,
#    'hole': 2,
#    'didnt': 1,
#    'match': 1,
#    'dont': 1,
#    'know': 1,
#    'beginner': 1,
#    'would': 1,
#    'able': 2,
#    'fix': 1,
#    'problem': 1,
#    'thank': 1,
#    'goodness': 1,
#    'husband': 1,
#    'drill': 1,
#    'new': 1,
#    'work': 1,
#    'around': 1},
#   'fake'),
#  ({'got daughter': 1,
#    'daughter obsessed': 1,
#    'obsessed bracelet': 1,
#    'bracelet making': 1,
#    'making trend': 1,
#    'trend okay': 1,
#    'okay price': 1,
#    'price quite': 1,
#    'quite broken': 1,
#    'broken snapped': 1,
#    'snapped it': 1,
#    'it purchase': 1,
#    'purchase i': 1,
#    'i would': 1,
#    'would repeat': 1,
#    'got': 1,
#    'daughter': 1,
#    'obsessed': 1,
#    'bracelet': 1,
#    'making': 1,
#    'trend': 1,
#    'okay': 1,
#    'price': 1,
#    'quite': 1,
#    'broken': 1,
#    'snapped': 1,
#    'it': 1,
#    'purchase': 1,
#    'i': 1,
#    'would': 1,
#    'repeat': 1},
#   'fake'),
#  ({'easy install': 1,
#    'install the': 1,
#    'the doorbell': 1,
#    'doorbell ring': 1,
#    'ring perfectly': 1,
#    'perfectly allowing': 1,
#    'allowing home': 1,
#    'home owner': 1,
#    'owner hear': 1,
#    'hear doorbell': 1,
#    'doorbell even': 1,
#    'even distance': 1,
#    'distance im': 1,
#    'im glad': 1,
#    'glad i': 1,
#    'i purchase': 1,
#    'easy': 1,
#    'install': 1,
#    'the': 1,
#    'doorbell': 2,
#    'ring': 1,
#    'perfectly': 1,
#    'allowing': 1,
#    'home': 1,
#    'owner': 1,
#    'hear': 1,
#    'even': 1,
#    'distance': 1,
#    'im': 1,
#    'glad': 1,
#    'i': 1,
#    'purchase': 1},
#   'fake'),
#  ({'super sharp': 1,
#    'sharp cut': 1,
#    'cut finger': 1,
#    'finger becasue': 1,
#    'becasue i': 1,
#    'i holding': 1,
#    'holding wrong': 1,
#    'wrong great': 1,
#    'great item': 1,
#    'item cheap': 1,
#    'cheap nice': 1,
#    'nice weight': 1,
#    'weight unlike': 1,
#    'unlike plastic': 1,
#    'plastic one': 1,
#    'super': 1,
#    'sharp': 1,
#    'cut': 1,
#    'finger': 1,
#    'becasue': 1,
#    'i': 1,
#    'holding': 1,
#    'wrong': 1,
#    'great': 1,
#    'item': 1,
#    'cheap': 1,
#    'nice': 1,
#    'weight': 1,
#    'unlike': 1,
#    'plastic': 1,
#    'one': 1},
#   'fake'),
#  ({'the cable': 1,
#    'cable temperamental': 1,
#    'temperamental message': 1,
#    'message keep': 1,
#    'keep coming': 1,
#    'coming iphone': 1,
#    'iphone saying': 1,
#    'saying something': 1,
#    'something along': 1,
#    'along line': 1,
#    'line unofficial': 1,
#    'unofficial device': 1,
#    'device may': 1,
#    'may work': 1,
#    'work properly': 1,
#    'properly sometimes': 1,
#    'sometimes work': 1,
#    'work sometimes': 1,
#    'sometimes doesnt': 1,
#    'doesnt sometimes': 1,
#    'sometimes i': 1,
#    'i dead': 1,
#    'dead phone': 1,
#    'phone borrow': 1,
#    'borrow friend': 1,
#    'friend official': 1,
#    'official charger': 1,
#    'charger get': 1,
#    'get work': 1,
#    'work i': 1,
#    'i really': 1,
#    'really would': 1,
#    'would recommend': 1,
#    'recommend product': 1,
#    'the': 1,
#    'cable': 1,
#    'temperamental': 1,
#    'message': 1,
#    'keep': 1,
#    'coming': 1,
#    'iphone': 1,
#    'saying': 1,
#    'something': 1,
#    'along': 1,
#    'line': 1,
#    'unofficial': 1,
#    'device': 1,
#    'may': 1,
#    'work': 3,
#    'properly': 1,
#    'sometimes': 3,
#    'doesnt': 1,
#    'i': 2,
#    'dead': 1,
#    'phone': 1,
#    'borrow': 1,
#    'friend': 1,
#    'official': 1,
#    'charger': 1,
#    'get': 1,
#    'really': 1,
#    'would': 1,
#    'recommend': 1,
#    'product': 1},
#   'fake'),
#  ({'i looking': 1,
#    'looking good': 1,
#    'good waffle': 1,
#    'waffle maker': 2,
#    'maker i': 1,
#    'i broke': 1,
#    'broke last': 1,
#    'last one': 1,
#    'one accident': 1,
#    'accident thing': 1,
#    'thing the': 1,
#    'the waffle': 1,
#    'waffle come': 1,
#    'come beautifully': 1,
#    'beautifully smell': 1,
#    'smell intoxicating': 1,
#    'intoxicating i': 1,
#    'i know': 1,
#    'know recipe': 1,
#    'recipe solely': 1,
#    'solely responsible': 1,
#    'responsible i': 1,
#    'i really': 1,
#    'really say': 1,
#    'say great': 1,
#    'great waffle': 1,
#    'i': 4,
#    'looking': 1,
#    'good': 1,
#    'waffle': 3,
#    'maker': 2,
#    'broke': 1,
#    'last': 1,
#    'one': 1,
#    'accident': 1,
#    'thing': 1,
#    'the': 1,
#    'come': 1,
#    'beautifully': 1,
#    'smell': 1,
#    'intoxicating': 1,
#    'know': 1,
#    'recipe': 1,
#    'solely': 1,
#    'responsible': 1,
#    'really': 1,
#    'say': 1,
#    'great': 1},
#   'fake'),
#  ({'wouldnt even': 1,
#    'even smack': 1,
#    'smack local': 1,
#    'local bum': 1,
#    'bum back': 1,
#    'back alley': 1,
#    'alley chinsey': 1,
#    'chinsey piece': 1,
#    'piece wood': 1,
#    'wood ': 1,
#    ' i': 1,
#    'i ordered': 1,
#    'ordered crap': 1,
#    'crap stick': 1,
#    'stick crappy': 1,
#    'crappy stick': 1,
#    'wouldnt': 1,
#    'even': 1,
#    'smack': 1,
#    'local': 1,
#    'bum': 1,
#    'back': 1,
#    'alley': 1,
#    'chinsey': 1,
#    'piece': 1,
#    'wood': 1,
#    '': 1,
#    'i': 1,
#    'ordered': 1,
#    'crap': 1,
#    'stick': 2,
#    'crappy': 1},
#   'fake'),
#  ({'it exactly': 1,
#    'exactly like': 1,
#    'like picture': 1,
#    'picture great': 1,
#    'great size': 1,
#    'size nice': 1,
#    'nice colour': 1,
#    'colour instruction': 1,
#    'instruction pack': 1,
#    'pack together': 1,
#    'together wasnt': 1,
#    'wasnt clear': 1,
#    'clear i': 1,
#    'i search': 1,
#    'search googleyoutube': 1,
#    'googleyoutube awhile': 1,
#    'awhile i': 1,
#    'i found': 1,
#    'found gonna': 1,
#    'gonna test': 1,
#    'test tent': 1,
#    'tent weekend': 1,
#    'weekend see': 1,
#    'see manage': 1,
#    'manage mothernatureto': 1,
#    'mothernatureto continued': 1,
#    'it': 1,
#    'exactly': 1,
#    'like': 1,
#    'picture': 1,
#    'great': 1,
#    'size': 1,
#    'nice': 1,
#    'colour': 1,
#    'instruction': 1,
#    'pack': 1,
#    'together': 1,
#    'wasnt': 1,
#    'clear': 1,
#    'i': 2,
#    'search': 1,
#    'googleyoutube': 1,
#    'awhile': 1,
#    'found': 1,
#    'gonna': 1,
#    'test': 1,
#    'tent': 1,
#    'weekend': 1,
#    'see': 1,
#    'manage': 1,
#    'mothernatureto': 1,
#    'continued': 1},
#   'fake'),
#  ({'i taking': 1,
#    'taking product': 1,
#    'product along': 1,
#    'along vitamin': 1,
#    'vitamin i': 1,
#    'i noticed': 1,
#    'noticed difference': 1,
#    'difference energy': 1,
#    'energy i': 1,
#    'i also': 1,
#    'also lost': 1,
#    'lost couple': 1,
#    'couple pound': 1,
#    'pound i': 1,
#    'i begun': 1,
#    'begun exercising': 1,
#    'exercising well': 1,
#    'i': 4,
#    'taking': 1,
#    'product': 1,
#    'along': 1,
#    'vitamin': 1,
#    'noticed': 1,
#    'difference': 1,
#    'energy': 1,
#    'also': 1,
#    'lost': 1,
#    'couple': 1,
#    'pound': 1,
#    'begun': 1,
#    'exercising': 1,
#    'well': 1},
#   'fake'),
#  ({'nice watch': 1,
#    'watch friend': 1,
#    'friend kid': 1,
#    'kid i': 1,
#    'i received': 1,
#    'received time': 1,
#    'time excellent': 1,
#    'excellent condition': 1,
#    'condition kid': 1,
#    'kid like': 1,
#    'like i': 1,
#    'i would': 1,
#    'would recommend': 1,
#    'recommend good': 1,
#    'good item': 1,
#    'item gift': 1,
#    'gift someone': 1,
#    'someone especially': 1,
#    'especially kid': 1,
#    'nice': 1,
#    'watch': 1,
#    'friend': 1,
#    'kid': 3,
#    'i': 2,
#    'received': 1,
#    'time': 1,
#    'excellent': 1,
#    'condition': 1,
#    'like': 1,
#    'would': 1,
#    'recommend': 1,
#    'good': 1,
#    'item': 1,
#    'gift': 1,
#    'someone': 1,
#    'especially': 1},
#   'fake'),
#  ({'i one': 1,
#    'one supcase': 1,
#    'supcase case': 1,
#    'case oddly': 1,
#    'oddly shaped': 1,
#    'shaped uncomfortable': 1,
#    'uncomfortable hold': 1,
#    'hold bulky': 1,
#    'bulky edge': 1,
#    'edge especially': 1,
#    'especially i': 1,
#    'i dont': 1,
#    'dont know': 1,
#    'know keep': 1,
#    'keep making': 1,
#    'making weird': 1,
#    'weird shaped': 1,
#    'shaped case': 1,
#    'case every': 1,
#    'every time': 1,
#    'i': 2,
#    'one': 1,
#    'supcase': 1,
#    'case': 2,
#    'oddly': 1,
#    'shaped': 2,
#    'uncomfortable': 1,
#    'hold': 1,
#    'bulky': 1,
#    'edge': 1,
#    'especially': 1,
#    'dont': 1,
#    'know': 1,
#    'keep': 1,
#    'making': 1,
#    'weird': 1,
#    'every': 1,
#    'time': 1},
#   'fake'),
#  ({'like many': 1,
#    'many different': 1,
#    'different setting': 1,
#    'setting nozzleits': 1,
#    'nozzleits really': 1,
#    'really powerwasher': 1,
#    'powerwasher love': 1,
#    'like': 1,
#    'many': 1,
#    'different': 1,
#    'setting': 1,
#    'nozzleits': 1,
#    'really': 1,
#    'powerwasher': 1,
#    'love': 1},
#   'fake'),
#  ({'glitter fell': 1,
#    'fell soon': 1,
#    'soon i': 1,
#    'i opened': 1,
#    'opened package': 1,
#    'package first': 1,
#    'first case': 1,
#    'case i': 1,
#    'i put': 1,
#    'put broke': 1,
#    'broke within': 1,
#    'within hour': 1,
#    'hour made': 1,
#    'made very': 1,
#    'very cheap': 1,
#    'cheap scratched': 1,
#    'scratched plastic': 1,
#    'plastic don': 1,
#    'don t': 1,
#    't buy': 1,
#    'glitter': 1,
#    'fell': 1,
#    'soon': 1,
#    'i': 2,
#    'opened': 1,
#    'package': 1,
#    'first': 1,
#    'case': 1,
#    'put': 1,
#    'broke': 1,
#    'within': 1,
#    'hour': 1,
#    'made': 1,
#    'very': 1,
#    'cheap': 1,
#    'scratched': 1,
#    'plastic': 1,
#    'don': 1,
#    't': 1,
#    'buy': 1},
#   'fake'),
#  ({'these super': 1,
#    'super flashlight': 1,
#    'flashlight great': 1,
#    'great price': 1,
#    'price they': 1,
#    'they small': 1,
#    'small enough': 1,
#    'enough fit': 1,
#    'fit pocket': 1,
#    'pocket the': 1,
#    'the package': 1,
#    'package includes': 1,
#    'includes rechargeable': 1,
#    'rechargeable battery': 1,
#    'battery charger': 1,
#    'charger theyre': 1,
#    'theyre blindingly': 1,
#    'blindingly bright': 1,
#    'bright include': 1,
#    'include zoomfocus': 1,
#    'zoomfocus function': 1,
#    'function strong': 1,
#    'strong metal': 1,
#    'metal construction': 1,
#    'construction 34o34': 1,
#    '34o34 ring': 1,
#    'ring seal': 1,
#    'seal 3': 1,
#    '3 mode': 1,
#    'mode operation': 1,
#    'these': 1,
#    'super': 1,
#    'flashlight': 1,
#    'great': 1,
#    'price': 1,
#    'they': 1,
#    'small': 1,
#    'enough': 1,
#    'fit': 1,
#    'pocket': 1,
#    'the': 1,
#    'package': 1,
#    'includes': 1,
#    'rechargeable': 1,
#    'battery': 1,
#    'charger': 1,
#    'theyre': 1,
#    'blindingly': 1,
#    'bright': 1,
#    'include': 1,
#    'zoomfocus': 1,
#    'function': 1,
#    'strong': 1,
#    'metal': 1,
#    'construction': 1,
#    '34o34': 1,
#    'ring': 1,
#    'seal': 1,
#    '3': 1,
#    'mode': 1,
#    'operation': 1},
#   'fake'),
#  ({'perhaps good': 1,
#    'good camera': 1,
#    'camera someone': 1,
#    'someone know': 1,
#    'know camera': 1,
#    'camera ': 1,
#    ' im': 1,
#    'im sure': 1,
#    'sure take': 1,
#    'take great': 1,
#    'great picture': 1,
#    'picture complicated': 1,
#    'complicated i': 1,
#    'i wanted': 1,
#    'wanted camera': 1,
#    'camera take': 1,
#    'take good': 1,
#    'good picture': 1,
#    'picture new': 1,
#    'new career': 1,
#    'career this': 1,
#    'this go': 1,
#    'go back': 1,
#    'perhaps': 1,
#    'good': 2,
#    'camera': 3,
#    'someone': 1,
#    'know': 1,
#    '': 1,
#    'im': 1,
#    'sure': 1,
#    'take': 2,
#    'great': 1,
#    'picture': 2,
#    'complicated': 1,
#    'i': 1,
#    'wanted': 1,
#    'new': 1,
#    'career': 1,
#    'this': 1,
#    'go': 1,
#    'back': 1},
#   'fake'),
#  ({'nothing new': 1,
#    'new book': 1,
#    'book ': 1,
#    ' already': 1,
#    'already read': 1,
#    'read something': 1,
#    'something master': 1,
#    'master financial': 1,
#    'financial life': 1,
#    'life book': 1,
#    'book much': 1,
#    'much help': 1,
#    'nothing': 1,
#    'new': 1,
#    'book': 2,
#    '': 1,
#    'already': 1,
#    'read': 1,
#    'something': 1,
#    'master': 1,
#    'financial': 1,
#    'life': 1,
#    'much': 1,
#    'help': 1},
#   'fake'),
#  ({'i briefly': 1,
#    'briefly describe': 1,
#    'describe ask': 1,
#    'ask specifically': 1,
#    'specifically improved': 1,
#    'improved obvious': 1,
#    'obvious weakness': 1,
#    'weakness purchasing': 1,
#    'purchasing the': 1,
#    'the crank': 1,
#    'crank connects': 1,
#    'connects directly': 1,
#    'directly lift': 1,
#    'lift ring': 1,
#    'ring umbrella': 1,
#    'umbrella string': 1,
#    'string feed': 1,
#    'feed main': 1,
#    'main pole': 1,
#    'i': 1,
#    'briefly': 1,
#    'describe': 1,
#    'ask': 1,
#    'specifically': 1,
#    'improved': 1,
#    'obvious': 1,
#    'weakness': 1,
#    'purchasing': 1,
#    'the': 1,
#    'crank': 1,
#    'connects': 1,
#    'directly': 1,
#    'lift': 1,
#    'ring': 1,
#    'umbrella': 1,
#    'string': 1,
#    'feed': 1,
#    'main': 1,
#    'pole': 1},
#   'fake'),
#  ({'i purchased': 2,
#    'purchased tv': 1,
#    'tv last': 1,
#    'last month': 1,
#    'month living': 1,
#    'living room': 1,
#    'room tv': 1,
#    'tv i': 1,
#    'i saw': 1,
#    'saw great': 1,
#    'great price': 1,
#    'price decent': 1,
#    'decent review': 1,
#    'review online': 1,
#    'online boy': 1,
#    'boy i': 1,
#    'i regret': 1,
#    'regret itbr': 1,
#    'itbr br': 1,
#    'br it': 3,
#    'it wasnt': 1,
#    'wasnt day': 1,
#    'day tv': 1,
#    'tv dead': 1,
#    'dead pixel': 1,
#    'pixel forming': 1,
#    'forming eye': 1,
#    'eye i': 1,
#    'i proceeded': 1,
#    'proceeded tell': 1,
#    'tell quality': 1,
#    'quality tv': 2,
#    'tv price': 1,
#    'price next': 1,
#    'next one': 1,
#    'one hdmi': 1,
#    'hdmi port': 1,
#    'port began': 1,
#    'began fail': 1,
#    'fail caused': 1,
#    'caused screen': 1,
#    'screen fuzzy': 1,
#    'fuzzy play': 1,
#    'play around': 1,
#    'around cord': 1,
#    'cord get': 1,
#    'get picture': 1,
#    'picture back': 1,
#    'back this': 1,
#    'this tv': 1,
#    'tv is': 1,
#    'is low': 1,
#    'low quality': 1,
#    'quality sure': 1,
#    'sure i': 1,
#    'i expected': 1,
#    'expected subperfect': 1,
#    'subperfect quality': 1,
#    'quality i': 1,
#    'i didnt': 1,
#    'didnt expect': 1,
#    'expect tv': 1,
#    'tv absolutely': 1,
#    'absolutely unwatchablebr': 1,
#    'unwatchablebr br': 1,
#    'br returning': 1,
#    'returning tv': 1,
#    'tv nightmare': 1,
#    'nightmare i': 1,
#    'i dont': 1,
#    'dont wish': 1,
#    'wish upon': 1,
#    'upon worst': 1,
#    'worst enemy': 1,
#    'enemy i': 1,
#    'i wish': 1,
#    'wish i': 1,
#    'i would': 1,
#    'would purchased': 1,
#    'purchased quality': 1,
#    'tv begin': 1,
#    'begin withbr': 1,
#    'withbr br': 1,
#    'br after': 1,
#    'after dealing': 1,
#    'dealing return': 1,
#    'return i': 1,
#    'purchased much': 1,
#    'much better': 1,
#    'better tv': 1,
#    'tv wayyy': 1,
#    'wayyy cheaperbr': 1,
#    'cheaperbr br': 1,
#    'br if': 1,
#    'if want': 1,
#    'want quality': 1,
#    'quality 60': 1,
#    '60 inch': 1,
#    'inch tv': 1,
#    'tv check': 1,
#    'check one': 1,
#    'one ': 1,
#    ' httpamznto1ozwtlsbr': 1,
#    'httpamznto1ozwtlsbr br': 1,
#    'it amazon': 1,
#    'amazon i': 1,
#    'i currently': 1,
#    'currently i': 1,
#    'i never': 1,
#    'never happierbr': 1,
#    'happierbr br': 1,
#    'it great': 1,
#    'great quality': 1,
#    'quality picture': 1,
#    'picture wasnt': 1,
#    'wasnt insanely': 1,
#    'insanely expensive': 1,
#    'expensive like': 1,
#    'like tv': 1,
#    'tv sale': 1,
#    'sale please': 1,
#    'please save': 1,
#    'save time': 1,
#    'time frustration': 1,
#    'frustration i': 1,
#    'i put': 1,
#    'i': 13,
#    'purchased': 3,
#    'tv': 11,
#    'last': 1,
#    'month': 1,
#    'living': 1,
#    'room': 1,
#    'saw': 1,
#    'great': 2,
#    'price': 2,
#    'decent': 1,
#    'review': 1,
#    'online': 1,
#    'boy': 1,
#    'regret': 1,
#    'itbr': 1,
#    'br': 6,
#    'it': 3,
#    'wasnt': 2,
#    'day': 1,
#    'dead': 1,
#    'pixel': 1,
#    'forming': 1,
#    'eye': 1,
#    'proceeded': 1,
#    'tell': 1,
#    'quality': 6,
#    'next': 1,
#    'one': 2,
#    'hdmi': 1,
#    'port': 1,
#    'began': 1,
#    'fail': 1,
#    'caused': 1,
#    'screen': 1,
#    'fuzzy': 1,
#    'play': 1,
#    'around': 1,
#    'cord': 1,
#    'get': 1,
#    'picture': 2,
#    'back': 1,
#    'this': 1,
#    'is': 1,
#    'low': 1,
#    'sure': 1,
#    'expected': 1,
#    'subperfect': 1,
#    'didnt': 1,
#    'expect': 1,
#    'absolutely': 1,
#    'unwatchablebr': 1,
#    'returning': 1,
#    'nightmare': 1,
#    'dont': 1,
#    'wish': 2,
#    'upon': 1,
#    'worst': 1,
#    'enemy': 1,
#    'would': 1,
#    'begin': 1,
#    'withbr': 1,
#    'after': 1,
#    'dealing': 1,
#    'return': 1,
#    'much': 1,
#    'better': 1,
#    'wayyy': 1,
#    'cheaperbr': 1,
#    'if': 1,
#    'want': 1,
#    '60': 1,
#    'inch': 1,
#    'check': 1,
#    '': 1,
#    'httpamznto1ozwtlsbr': 1,
#    'amazon': 1,
#    'currently': 1,
#    'never': 1,
#    'happierbr': 1,
#    'insanely': 1,
#    'expensive': 1,
#    'like': 1,
#    'sale': 1,
#    'please': 1,
#    'save': 1,
#    'time': 1,
#    'frustration': 1,
#    'put': 1},
#   'fake'),
#  ({'for experienced': 1,
#    'experienced user': 1,
#    'user may': 1,
#    'may still': 1,
#    'still work': 1,
#    'work maybe': 1,
#    'maybe want': 1,
#    'want one': 1,
#    'one those': 1,
#    'those starting': 1,
#    'starting great': 1,
#    'great price': 1,
#    'price need': 1,
#    'need something': 1,
#    'something like': 1,
#    'like you': 1,
#    'you wont': 1,
#    'wont regret': 1,
#    'regret could': 1,
#    'could minor': 1,
#    'minor adjustment': 1,
#    'adjustment reason': 1,
#    'reason i': 1,
#    'i give': 1,
#    'give 4': 1,
#    '4 star': 1,
#    'for': 1,
#    'experienced': 1,
#    'user': 1,
#    'may': 1,
#    'still': 1,
#    'work': 1,
#    'maybe': 1,
#    'want': 1,
#    'one': 1,
#    'those': 1,
#    'starting': 1,
#    'great': 1,
#    'price': 1,
#    'need': 1,
#    'something': 1,
#    'like': 1,
#    'you': 1,
#    'wont': 1,
#    'regret': 1,
#    'could': 1,
#    'minor': 1,
#    'adjustment': 1,
#    'reason': 1,
#    'i': 1,
#    'give': 1,
#    '4': 1,
#    'star': 1},
#   'fake'),
#  ({'there question': 1,
#    'question goodness': 1,
#    'goodness camera': 1,
#    'camera the': 1,
#    'the product': 1,
#    'product good': 1,
#    'good new': 1,
#    'new one': 1,
#    'one except': 1,
#    'except warranty': 1,
#    'warranty time': 1,
#    'time i': 1,
#    'i trust': 1,
#    'trust brand': 1,
#    'brand inspected': 1,
#    'inspected reconditioned': 1,
#    'reconditioned factory': 1,
#    'factory i': 1,
#    'i rest': 1,
#    'rest faith': 1,
#    'there': 1,
#    'question': 1,
#    'goodness': 1,
#    'camera': 1,
#    'the': 1,
#    'product': 1,
#    'good': 1,
#    'new': 1,
#    'one': 1,
#    'except': 1,
#    'warranty': 1,
#    'time': 1,
#    'i': 2,
#    'trust': 1,
#    'brand': 1,
#    'inspected': 1,
#    'reconditioned': 1,
#    'factory': 1,
#    'rest': 1,
#    'faith': 1},
#   'fake'),
#  ({'i rescue': 1,
#    'rescue boxer': 1,
#    'boxer i': 1,
#    'i tried': 2,
#    'tried brushing': 1,
#    'brushing usual': 1,
#    'usual brush': 1,
#    'brush would': 1,
#    'would run': 1,
#    'run away': 1,
#    'away the': 1,
#    'the first': 1,
#    'first time': 1,
#    'time i': 1,
#    'tried ran': 1,
#    'ran away': 1,
#    'away realized': 1,
#    'realized felt': 1,
#    'felt good': 1,
#    'i': 3,
#    'rescue': 1,
#    'boxer': 1,
#    'tried': 2,
#    'brushing': 1,
#    'usual': 1,
#    'brush': 1,
#    'would': 1,
#    'run': 1,
#    'away': 2,
#    'the': 1,
#    'first': 1,
#    'time': 1,
#    'ran': 1,
#    'realized': 1,
#    'felt': 1,
#    'good': 1},
#   'fake'),
#  ({'the picture': 1,
#    'picture made': 1,
#    'made seem': 1,
#    'seem simple': 1,
#    'simple however': 1,
#    'however blazekey': 1,
#    'blazekey app': 1,
#    'app would': 1,
#    'would even': 1,
#    'even install': 1,
#    'install q': 1,
#    'q keybr': 1,
#    'keybr do': 1,
#    'do waste': 1,
#    'waste time': 1,
#    'time crap': 1,
#    'the': 1,
#    'picture': 1,
#    'made': 1,
#    'seem': 1,
#    'simple': 1,
#    'however': 1,
#    'blazekey': 1,
#    'app': 1,
#    'would': 1,
#    'even': 1,
#    'install': 1,
#    'q': 1,
#    'keybr': 1,
#    'do': 1,
#    'waste': 1,
#    'time': 1,
#    'crap': 1},
#   'fake'),
#  ({'we thought': 1,
#    'thought good': 1,
#    'good piece': 1,
#    'piece end': 1,
#    'end yard': 1,
#    'yard neighborhood': 1,
#    'neighborhood lake': 1,
#    'lake there': 1,
#    'there spotted': 1,
#    'spotted water': 1,
#    'water from': 1,
#    'from afar': 1,
#    'afar look': 1,
#    'look exactly': 1,
#    'exactly like': 1,
#    'like one': 1,
#    'one real': 1,
#    'real bird': 1,
#    'we': 1,
#    'thought': 1,
#    'good': 1,
#    'piece': 1,
#    'end': 1,
#    'yard': 1,
#    'neighborhood': 1,
#    'lake': 1,
#    'there': 1,
#    'spotted': 1,
#    'water': 1,
#    'from': 1,
#    'afar': 1,
#    'look': 1,
#    'exactly': 1,
#    'like': 1,
#    'one': 1,
#    'real': 1,
#    'bird': 1},
#   'fake'),
#  ({'bought one': 1,
#    'one dog': 1,
#    'dog the': 1,
#    'the dog': 1,
#    'dog seem': 1,
#    'seem like': 1,
#    'like alot': 1,
#    'alot so': 1,
#    'so far': 1,
#    'far canvas': 1,
#    'canvas stood': 1,
#    'stood scratching': 1,
#    'scratching trying': 1,
#    'trying make': 1,
#    'make nest': 1,
#    'nest it': 1,
#    'it didnt': 1,
#    'didnt quite': 1,
#    'quite fit': 1,
#    'fit together': 1,
#    'together little': 1,
#    'little balance': 1,
#    'bought': 1,
#    'one': 1,
#    'dog': 2,
#    'the': 1,
#    'seem': 1,
#    'like': 1,
#    'alot': 1,
#    'so': 1,
#    'far': 1,
#    'canvas': 1,
#    'stood': 1,
#    'scratching': 1,
#    'trying': 1,
#    'make': 1,
#    'nest': 1,
#    'it': 1,
#    'didnt': 1,
#    'quite': 1,
#    'fit': 1,
#    'together': 1,
#    'little': 1,
#    'balance': 1},
#   'fake'),
#  ({'these speaker': 1,
#    'speaker fine': 1,
#    'fine looking': 1,
#    'looking general': 1,
#    'general audio': 1,
#    'audio however': 1,
#    'however price': 1,
#    'price i': 1,
#    'i expected': 1,
#    'expected better': 1,
#    'better clarity': 1,
#    'clarity upper': 1,
#    'upper range': 1,
#    'range music': 1,
#    'music seems': 1,
#    'seems little': 1,
#    'little flat': 1,
#    'flat mid': 1,
#    'mid bass': 1,
#    'bass good': 1,
#    'good size': 1,
#    'size system': 1,
#    'these': 1,
#    'speaker': 1,
#    'fine': 1,
#    'looking': 1,
#    'general': 1,
#    'audio': 1,
#    'however': 1,
#    'price': 1,
#    'i': 1,
#    'expected': 1,
#    'better': 1,
#    'clarity': 1,
#    'upper': 1,
#    'range': 1,
#    'music': 1,
#    'seems': 1,
#    'little': 1,
#    'flat': 1,
#    'mid': 1,
#    'bass': 1,
#    'good': 1,
#    'size': 1,
#    'system': 1},
#   'fake'),
#  ({'i got': 2,
#    'got give': 1,
#    'give new': 1,
#    'new headset': 1,
#    'headset try': 1,
#    'try i': 1,
#    'i wish': 1,
#    'wish i': 1,
#    'i wouldnt': 1,
#    'wouldnt within': 1,
#    'within first': 1,
#    'first week': 1,
#    'week one': 1,
#    'one speaker': 1,
#    'speaker died': 1,
#    'died overall': 1,
#    'overall sound': 1,
#    'sound quality': 2,
#    'quality i': 1,
#    'i looking': 1,
#    'looking price': 1,
#    'price the': 1,
#    'the look': 1,
#    'look feel': 1,
#    'feel cool': 1,
#    'cool definitely': 1,
#    'definitely work': 1,
#    'work done': 1,
#    'done sold': 1,
#    'sold 100br': 1,
#    '100br br': 1,
#    'br after': 1,
#    'after dealing': 1,
#    'dealing i': 1,
#    'got good': 1,
#    'good headset': 1,
#    'headset i': 1,
#    'i absolutely': 1,
#    'absolutely love': 1,
#    'love the': 1,
#    'the sound': 1,
#    'quality great': 1,
#    'great i': 1,
#    'i havent': 1,
#    'havent found': 1,
#    'found single': 1,
#    'single thing': 1,
#    'thing complain': 1,
#    'complain two': 1,
#    'two month': 1,
#    'month use': 1,
#    'use i': 1,
#    'i wear': 1,
#    'wear hour': 1,
#    'hour end': 1,
#    'end issuebr': 1,
#    'issuebr br': 1,
#    'br if': 1,
#    'if want': 1,
#    'want great': 1,
#    'great headset': 1,
#    'headset check': 1,
#    'check pair': 1,
#    'pair amazon': 1,
#    'amazon 62': 1,
#    '62 httpamznto1qp9fhdbr': 1,
#    'httpamznto1qp9fhdbr br': 1,
#    'br i': 1,
#    'i hope': 1,
#    'hope i': 1,
#    'i could': 1,
#    'could help': 1,
#    'help others': 1,
#    'others sharing': 1,
#    'sharing experience': 1,
#    'experience headset': 1,
#    'headset wont': 1,
#    'wont regret': 1,
#    'regret getting': 1,
#    'getting pair': 1,
#    'pair i': 1,
#    'i': 11,
#    'got': 2,
#    'give': 1,
#    'new': 1,
#    'headset': 4,
#    'try': 1,
#    'wish': 1,
#    'wouldnt': 1,
#    'within': 1,
#    'first': 1,
#    'week': 1,
#    'one': 1,
#    'speaker': 1,
#    'died': 1,
#    'overall': 1,
#    'sound': 2,
#    'quality': 2,
#    'looking': 1,
#    'price': 1,
#    'the': 2,
#    'look': 1,
#    'feel': 1,
#    'cool': 1,
#    'definitely': 1,
#    'work': 1,
#    'done': 1,
#    'sold': 1,
#    '100br': 1,
#    'br': 3,
#    'after': 1,
#    'dealing': 1,
#    'good': 1,
#    'absolutely': 1,
#    'love': 1,
#    'great': 2,
#    'havent': 1,
#    'found': 1,
#    'single': 1,
#    'thing': 1,
#    'complain': 1,
#    'two': 1,
#    'month': 1,
#    'use': 1,
#    'wear': 1,
#    'hour': 1,
#    'end': 1,
#    'issuebr': 1,
#    'if': 1,
#    'want': 1,
#    'check': 1,
#    'pair': 2,
#    'amazon': 1,
#    '62': 1,
#    'httpamznto1qp9fhdbr': 1,
#    'hope': 1,
#    'could': 1,
#    'help': 1,
#    'others': 1,
#    'sharing': 1,
#    'experience': 1,
#    'wont': 1,
#    'regret': 1,
#    'getting': 1},
#   'fake'),
#  ({'it hard': 1,
#    'hard control': 1,
#    'control phone': 1,
#    'phone plasticbr': 1,
#    'plasticbr br': 1,
#    'br i': 1,
#    'i get': 1,
#    'get access': 1,
#    'access app': 1,
#    'app put': 1,
#    'put back': 1,
#    'back inthe': 1,
#    'inthe armband': 1,
#    'armband however': 1,
#    'however comfortable': 1,
#    'comfortable function': 1,
#    'function excellent': 1,
#    'it': 1,
#    'hard': 1,
#    'control': 1,
#    'phone': 1,
#    'plasticbr': 1,
#    'br': 1,
#    'i': 1,
#    'get': 1,
#    'access': 1,
#    'app': 1,
#    'put': 1,
#    'back': 1,
#    'inthe': 1,
#    'armband': 1,
#    'however': 1,
#    'comfortable': 1,
#    'function': 1,
#    'excellent': 1},
#   'fake'),
#  ({'this make': 1,
#    'make fast': 1,
#    'fast work': 1,
#    'work cleaning': 1,
#    'cleaning bath': 1,
#    'bath toy': 1,
#    'toy the': 1,
#    'the thing': 1,
#    'thing could': 1,
#    'could make': 1,
#    'make better': 1,
#    'better would': 1,
#    'would better': 1,
#    'better suction': 1,
#    'suction cup': 2,
#    'cup it': 1,
#    'it fell': 1,
#    'fell right': 1,
#    'right tile': 1,
#    'tile weight': 1,
#    'weight toy': 1,
#    'toy added': 1,
#    'added i': 1,
#    'i got': 1,
#    'got new': 1,
#    'new suction': 1,
#    'cup walmart': 1,
#    'walmart vaseline': 1,
#    'vaseline trick': 1,
#    'trick now': 1,
#    'now joy': 1,
#    'this': 1,
#    'make': 2,
#    'fast': 1,
#    'work': 1,
#    'cleaning': 1,
#    'bath': 1,
#    'toy': 2,
#    'the': 1,
#    'thing': 1,
#    'could': 1,
#    'better': 2,
#    'would': 1,
#    'suction': 2,
#    'cup': 2,
#    'it': 1,
#    'fell': 1,
#    'right': 1,
#    'tile': 1,
#    'weight': 1,
#    'added': 1,
#    'i': 1,
#    'got': 1,
#    'new': 1,
#    'walmart': 1,
#    'vaseline': 1,
#    'trick': 1,
#    'now': 1,
#    'joy': 1},
#   'fake'),
#  ({'interesting movie': 1,
#    'movie military': 1,
#    'military school': 1,
#    'school one': 1,
#    'one portray': 1,
#    'portray character': 1,
#    'character cardboard': 1,
#    'cardboard cutout': 1,
#    'cutout happens': 1,
#    'happens often': 1,
#    'often movie': 1,
#    'movie teen': 1,
#    'teen real': 1,
#    'real people': 1,
#    'people depth': 1,
#    'depth ': 1,
#    ' it': 1,
#    'it get': 1,
#    'get slow': 1,
#    'slow start': 1,
#    'start well': 1,
#    'well crafted': 1,
#    'crafted plot': 1,
#    'plot one': 1,
#    'one stretch': 1,
#    'stretch credulity': 1,
#    'credulity word': 1,
#    'word everything': 1,
#    'everything turn': 1,
#    'turn audience': 1,
#    'audience want': 1,
#    'interesting': 1,
#    'movie': 2,
#    'military': 1,
#    'school': 1,
#    'one': 2,
#    'portray': 1,
#    'character': 1,
#    'cardboard': 1,
#    'cutout': 1,
#    'happens': 1,
#    'often': 1,
#    'teen': 1,
#    'real': 1,
#    'people': 1,
#    'depth': 1,
#    '': 1,
#    'it': 1,
#    'get': 1,
#    'slow': 1,
#    'start': 1,
#    'well': 1,
#    'crafted': 1,
#    'plot': 1,
#    'stretch': 1,
#    'credulity': 1,
#    'word': 1,
#    'everything': 1,
#    'turn': 1,
#    'audience': 1,
#    'want': 1},
#   'fake'),
#  ({'bought save': 1,
#    'save counter': 1,
#    'counter space': 1,
#    'space pretty': 1,
#    'pretty wellmade': 1,
#    'wellmade handleholding': 1,
#    'handleholding bar': 1,
#    'bar short': 1,
#    'short keep': 1,
#    'keep spoon': 1,
#    'spoon falling': 1,
#    'falling without': 1,
#    'without applying': 1,
#    'applying extra': 1,
#    'extra effort': 1,
#    'effort often': 1,
#    'often caused': 1,
#    'caused mess': 1,
#    'mess only': 1,
#    'only use': 1,
#    'use big': 1,
#    'big utensil': 1,
#    'utensil small': 1,
#    'small one': 1,
#    'one fall': 1,
#    'fall good': 1,
#    'good one': 1,
#    'one time': 1,
#    'bought': 1,
#    'save': 1,
#    'counter': 1,
#    'space': 1,
#    'pretty': 1,
#    'wellmade': 1,
#    'handleholding': 1,
#    'bar': 1,
#    'short': 1,
#    'keep': 1,
#    'spoon': 1,
#    'falling': 1,
#    'without': 1,
#    'applying': 1,
#    'extra': 1,
#    'effort': 1,
#    'often': 1,
#    'caused': 1,
#    'mess': 1,
#    'only': 1,
#    'use': 1,
#    'big': 1,
#    'utensil': 1,
#    'small': 1,
#    'one': 2,
#    'fall': 1,
#    'good': 1,
#    'time': 1},
#   'fake'),
#  ({'im terribly': 1,
#    'terribly fussy': 1,
#    'fussy come': 1,
#    'come fashion': 1,
#    'fashion id': 1,
#    'id rather': 1,
#    'rather book': 1,
#    'book bag': 1,
#    'bag cosmetic': 1,
#    'cosmetic product': 1,
#    'product bag': 1,
#    'bag suffice': 1,
#    'suffice it': 1,
#    'it meet': 1,
#    'meet need': 1,
#    'need i': 1,
#    'i intended': 1,
#    'intended i': 1,
#    'i chose': 1,
#    'im': 1,
#    'terribly': 1,
#    'fussy': 1,
#    'come': 1,
#    'fashion': 1,
#    'id': 1,
#    'rather': 1,
#    'book': 1,
#    'bag': 2,
#    'cosmetic': 1,
#    'product': 1,
#    'suffice': 1,
#    'it': 1,
#    'meet': 1,
#    'need': 1,
#    'i': 2,
#    'intended': 1,
#    'chose': 1},
#   'fake'),
#  ({'i use': 1,
#    'use gadget': 1,
#    'gadget kitchen': 1,
#    'kitchen also': 1,
#    'also decoration': 1,
#    'decoration if': 1,
#    'if love': 1,
#    'love fun': 1,
#    'fun ': 1,
#    ' right': 1,
#    'right one': 1,
#    'one also': 1,
#    'also great': 1,
#    'great gift': 1,
#    'gift just': 1,
#    'just hanging': 1,
#    'hanging kitchen': 1,
#    'kitchen fun': 1,
#    'fun product': 1,
#    'i': 1,
#    'use': 1,
#    'gadget': 1,
#    'kitchen': 2,
#    'also': 2,
#    'decoration': 1,
#    'if': 1,
#    'love': 1,
#    'fun': 2,
#    '': 1,
#    'right': 1,
#    'one': 1,
#    'great': 1,
#    'gift': 1,
#    'just': 1,
#    'hanging': 1,
#    'product': 1},
#   'fake'),
#  ({'the image': 1,
#    'image nice': 1,
#    'nice first': 1,
#    'first time': 1,
#    'time i': 1,
#    'i used': 1,
#    'used classroom': 1,
#    'classroom week': 1,
#    'week picture': 1,
#    'picture barely': 1,
#    'barely registered': 1,
#    'registered i': 1,
#    'i couldnt': 1,
#    'couldnt tell': 1,
#    'tell going': 1,
#    'going i': 1,
#    'i concluded': 1,
#    'concluded projector': 1,
#    'projector simply': 1,
#    'simply failed': 1,
#    'the': 1,
#    'image': 1,
#    'nice': 1,
#    'first': 1,
#    'time': 1,
#    'i': 3,
#    'used': 1,
#    'classroom': 1,
#    'week': 1,
#    'picture': 1,
#    'barely': 1,
#    'registered': 1,
#    'couldnt': 1,
#    'tell': 1,
#    'going': 1,
#    'concluded': 1,
#    'projector': 1,
#    'simply': 1,
#    'failed': 1},
#   'fake'),
#  ({'i never': 1,
#    'never tried': 1,
#    'tried sw': 1,
#    'sw baked': 1,
#    'baked bean': 1,
#    'bean gone': 1,
#    'gone i': 1,
#    'i doubt': 1,
#    'doubt ill': 1,
#    'ill ever': 1,
#    'ever try': 1,
#    'try the': 1,
#    'the bean': 1,
#    'bean small': 1,
#    'small sauce': 1,
#    'sauce watery': 1,
#    'watery anemictasting': 1,
#    'anemictasting really': 1,
#    'really bland': 1,
#    'bland very': 1,
#    'very disappointing': 1,
#    'disappointing product': 1,
#    'i': 2,
#    'never': 1,
#    'tried': 1,
#    'sw': 1,
#    'baked': 1,
#    'bean': 2,
#    'gone': 1,
#    'doubt': 1,
#    'ill': 1,
#    'ever': 1,
#    'try': 1,
#    'the': 1,
#    'small': 1,
#    'sauce': 1,
#    'watery': 1,
#    'anemictasting': 1,
#    'really': 1,
#    'bland': 1,
#    'very': 1,
#    'disappointing': 1,
#    'product': 1},
#   'fake'),
#  ({'i got': 3,
#    'got hoping': 1,
#    'hoping get': 1,
#    'get decent': 1,
#    'decent set': 1,
#    'set home': 1,
#    'home didnt': 1,
#    'didnt turn': 1,
#    'turn way': 1,
#    'way first': 1,
#    'first smell': 1,
#    'smell set': 1,
#    'set nothing': 1,
#    'nothing short': 1,
#    'short toxic': 1,
#    'toxic the': 1,
#    'the chemical': 1,
#    'chemical smell': 1,
#    'smell come': 1,
#    'come nauseating': 1,
#    'nauseating fill': 1,
#    'fill entire': 1,
#    'entire room': 1,
#    'room i': 1,
#    'i tried': 1,
#    'tried wiping': 1,
#    'wiping didnt': 1,
#    'didnt seem': 1,
#    'seem help': 1,
#    'help inspection': 1,
#    'inspection noticed': 1,
#    'noticed warning': 1,
#    'warning label': 1,
#    'label chemical': 1,
#    'chemical used': 1,
#    'used linked': 1,
#    'linked cancer': 1,
#    'cancer birth': 1,
#    'birth defect': 1,
#    'defect also': 1,
#    'also kit': 1,
#    'kit doesnt': 1,
#    'doesnt even': 1,
#    'even come': 1,
#    'come enough': 1,
#    'enough weight': 1,
#    'weight even': 1,
#    'even reach': 1,
#    'reach 40': 1,
#    '40 lb': 1,
#    'lb i': 1,
#    'i weighed': 1,
#    'weighed weight': 1,
#    'weight equal': 1,
#    'equal 38': 1,
#    '38 lb': 1,
#    'lb 4': 1,
#    '4 lb': 1,
#    'lb bar': 1,
#    'bar itselfbr': 1,
#    'itselfbr br': 1,
#    'br after': 1,
#    'after getting': 1,
#    'getting rid': 1,
#    'rid i': 1,
#    'got set': 1,
#    'set dumbbell': 2,
#    'dumbbell i': 1,
#    'i absolutely': 1,
#    'absolutely love': 1,
#    'love i': 1,
#    'got around': 1,
#    'around month': 1,
#    'month ago': 1,
#    'ago i': 1,
#    'i cant': 1,
#    'cant find': 1,
#    'find single': 1,
#    'single thing': 1,
#    'thing complain': 1,
#    'complain the': 1,
#    'the max': 1,
#    'max weight': 1,
#    'weight combination': 1,
#    'combination weight': 1,
#    'weight included': 1,
#    'included endless': 1,
#    'endless im': 1,
#    'im happy': 1,
#    'happy i': 1,
#    'i bought': 1,
#    'bought setbr': 1,
#    'setbr br': 1,
#    'br if': 1,
#    'if want': 1,
#    'want quality': 1,
#    'quality set': 1,
#    'dumbbell get': 1,
#    'get set': 1,
#    'set i': 1,
#    'i amazon': 1,
#    'amazon 62': 1,
#    '62 httpamznto1r0binnbr': 1,
#    'httpamznto1r0binnbr br': 1,
#    'br i': 1,
#    'i hope': 1,
#    'hope i': 1,
#    'i could': 1,
#    'could help': 1,
#    'help point': 1,
#    'point others': 1,
#    'others right': 1,
#    'right direction': 1,
#    'direction keep': 1,
#    'keep making': 1,
#    'making mistake': 1,
#    'mistake i': 1,
#    'i': 12,
#    'got': 3,
#    'hoping': 1,
#    'get': 2,
#    'decent': 1,
#    'set': 5,
#    'home': 1,
#    'didnt': 2,
#    'turn': 1,
#    'way': 1,
#    'first': 1,
#    'smell': 2,
#    'nothing': 1,
#    'short': 1,
#    'toxic': 1,
#    'the': 2,
#    'chemical': 2,
#    'come': 2,
#    'nauseating': 1,
#    'fill': 1,
#    'entire': 1,
#    'room': 1,
#    'tried': 1,
#    'wiping': 1,
#    'seem': 1,
#    'help': 2,
#    'inspection': 1,
#    'noticed': 1,
#    'warning': 1,
#    'label': 1,
#    'used': 1,
#    'linked': 1,
#    'cancer': 1,
#    'birth': 1,
#    'defect': 1,
#    'also': 1,
#    'kit': 1,
#    'doesnt': 1,
#    'even': 2,
#    'enough': 1,
#    'weight': 4,
#    'reach': 1,
#    '40': 1,
#    'lb': 3,
#    'weighed': 1,
#    'equal': 1,
#    '38': 1,
#    '4': 1,
#    'bar': 1,
#    'itselfbr': 1,
#    'br': 3,
#    'after': 1,
#    'getting': 1,
#    'rid': 1,
#    'dumbbell': 2,
#    'absolutely': 1,
#    'love': 1,
#    'around': 1,
#    'month': 1,
#    'ago': 1,
#    'cant': 1,
#    'find': 1,
#    'single': 1,
#    'thing': 1,
#    'complain': 1,
#    'max': 1,
#    'combination': 1,
#    'included': 1,
#    'endless': 1,
#    'im': 1,
#    'happy': 1,
#    'bought': 1,
#    'setbr': 1,
#    'if': 1,
#    'want': 1,
#    'quality': 1,
#    'amazon': 1,
#    '62': 1,
#    'httpamznto1r0binnbr': 1,
#    'hope': 1,
#    'could': 1,
#    'point': 1,
#    'others': 1,
#    'right': 1,
#    'direction': 1,
#    'keep': 1,
#    'making': 1,
#    'mistake': 1},
#   'fake'),
#  ({'what really': 1,
#    'really matter': 1,
#    'matter i': 1,
#    'i guess': 1,
#    'guess son': 1,
#    'son love': 1,
#    'love i': 1,
#    'i feel': 1,
#    'feel like': 1,
#    'like stomping': 1,
#    'stomping leaf': 1,
#    'leaf hanging': 1,
#    'hanging around': 1,
#    'around go': 1,
#    'go oh': 1,
#    'oh well': 1,
#    'what': 1,
#    'really': 1,
#    'matter': 1,
#    'i': 2,
#    'guess': 1,
#    'son': 1,
#    'love': 1,
#    'feel': 1,
#    'like': 1,
#    'stomping': 1,
#    'leaf': 1,
#    'hanging': 1,
#    'around': 1,
#    'go': 1,
#    'oh': 1,
#    'well': 1},
#   'fake'),
#  ({'i difficult': 1,
#    'difficult time': 1,
#    'time reestablish': 1,
#    'reestablish network': 1,
#    'network computer': 1,
#    'computer network': 1,
#    'network could': 1,
#    'could print': 1,
#    'print connected': 1,
#    'connected printer': 1,
#    'printer even': 1,
#    'even one': 1,
#    'one computer': 1,
#    'computer cannot': 1,
#    'cannot print': 1,
#    'print laser': 1,
#    'laser printer': 1,
#    'printer print': 1,
#    'print inkjet': 1,
#    'inkjet someone': 1,
#    'someone blamed': 1,
#    'blamed apple': 1,
#    'apple wired': 1,
#    'wired router': 1,
#    'i': 1,
#    'difficult': 1,
#    'time': 1,
#    'reestablish': 1,
#    'network': 2,
#    'computer': 2,
#    'could': 1,
#    'print': 3,
#    'connected': 1,
#    'printer': 2,
#    'even': 1,
#    'one': 1,
#    'cannot': 1,
#    'laser': 1,
#    'inkjet': 1,
#    'someone': 1,
#    'blamed': 1,
#    'apple': 1,
#    'wired': 1,
#    'router': 1},
#   'fake'),
#  ({'a lot': 1,
#    'lot smaller': 1,
#    'smaller i': 1,
#    'i imagined': 1,
#    'imagined the': 1,
#    'the picture': 1,
#    'picture look': 1,
#    'look great': 1,
#    'great look': 1,
#    'look ok': 1,
#    'ok i': 1,
#    'i using': 1,
#    'using i': 1,
#    'i intended': 1,
#    'intended i': 1,
#    'i wanted': 1,
#    'wanted use': 1,
#    'use lounge': 1,
#    'lounge chair': 1,
#    'chair back': 1,
#    'back low': 1,
#    'low long': 1,
#    'long enough': 1,
#    'enough someone': 1,
#    'someone 5834': 1,
#    '5834 i': 1,
#    'i would': 1,
#    'would say': 1,
#    'say 5334': 1,
#    '5334 would': 1,
#    'would work': 1,
#    'work look': 1,
#    'look measurement': 1,
#    'measurement making': 1,
#    'making purchase': 1,
#    'purchase i': 1,
#    'i set': 1,
#    'set 30': 1,
#    '30 day': 1,
#    'day i': 1,
#    'i make': 1,
#    'make use': 1,
#    'use nice': 1,
#    'nice storage': 1,
#    'storage i': 1,
#    'i sit': 1,
#    'sit bit': 1,
#    'bit lounge': 1,
#    'lounge long': 1,
#    'a': 1,
#    'lot': 1,
#    'smaller': 1,
#    'i': 8,
#    'imagined': 1,
#    'the': 1,
#    'picture': 1,
#    'look': 3,
#    'great': 1,
#    'ok': 1,
#    'using': 1,
#    'intended': 1,
#    'wanted': 1,
#    'use': 2,
#    'lounge': 2,
#    'chair': 1,
#    'back': 1,
#    'low': 1,
#    'long': 2,
#    'enough': 1,
#    'someone': 1,
#    '5834': 1,
#    'would': 2,
#    'say': 1,
#    '5334': 1,
#    'work': 1,
#    'measurement': 1,
#    'making': 1,
#    'purchase': 1,
#    'set': 1,
#    '30': 1,
#    'day': 1,
#    'make': 1,
#    'nice': 1,
#    'storage': 1,
#    'sit': 1,
#    'bit': 1},
#   'fake'),
#  ({'so like': 1,
#    'like everyone': 1,
#    'everyone else': 1,
#    'else i': 1,
#    'i skeptical': 1,
#    'skeptical ordering': 1,
#    'ordering bed': 1,
#    'bed online': 1,
#    'online without': 1,
#    'without testing': 1,
#    'testing first': 1,
#    'first i': 1,
#    'i definitely': 1,
#    'definitely not': 1,
#    'not disappointed': 1,
#    'disappointed this': 1,
#    'this comfortable': 1,
#    'comfortable bed': 1,
#    'bed i': 1,
#    'i in': 1,
#    'in love': 1,
#    'so': 1,
#    'like': 1,
#    'everyone': 1,
#    'else': 1,
#    'i': 3,
#    'skeptical': 1,
#    'ordering': 1,
#    'bed': 2,
#    'online': 1,
#    'without': 1,
#    'testing': 1,
#    'first': 1,
#    'definitely': 1,
#    'not': 1,
#    'disappointed': 1,
#    'this': 1,
#    'comfortable': 1,
#    'in': 1,
#    'love': 1},
#   'fake'),
#  ({'much smaller': 1,
#    'smaller expected': 1,
#    'expected the': 1,
#    'the description': 1,
#    'description really': 1,
#    'really indicate': 1,
#    'indicate mini': 1,
#    'mini donut': 1,
#    'donut pan': 1,
#    'pan im': 1,
#    'im disappointed': 1,
#    'disappointed pan': 1,
#    'pan decent': 1,
#    'decent quality': 1,
#    'quality also': 1,
#    'also i': 1,
#    'i receive': 1,
#    'receive recipe': 1,
#    'recipe mentioned': 1,
#    'mentioned description': 1,
#    'much': 1,
#    'smaller': 1,
#    'expected': 1,
#    'the': 1,
#    'description': 2,
#    'really': 1,
#    'indicate': 1,
#    'mini': 1,
#    'donut': 1,
#    'pan': 2,
#    'im': 1,
#    'disappointed': 1,
#    'decent': 1,
#    'quality': 1,
#    'also': 1,
#    'i': 1,
#    'receive': 1,
#    'recipe': 1,
#    'mentioned': 1},
#   'fake'),
#  ({'it ok': 1,
#    'ok when': 1,
#    'when i': 1,
#    'i went': 1,
#    'went assemble': 1,
#    'assemble leg': 1,
#    'leg i': 1,
#    'i found': 1,
#    'found two': 1,
#    'two leg': 1,
#    'leg wide': 1,
#    'wide crack': 1,
#    'crack going': 1,
#    'going entire': 1,
#    'entire side': 1,
#    'side luckily': 1,
#    'luckily crack': 1,
#    'crack could': 1,
#    'could face': 1,
#    'face inside': 1,
#    'inside sight': 1,
#    'sight decided': 1,
#    'decided send': 1,
#    'send back': 1,
#    'back thinking': 1,
#    'thinking leg': 1,
#    'leg split': 1,
#    'split two': 1,
#    'two piece': 2,
#    'piece i': 1,
#    'i superglue': 1,
#    'superglue back': 1,
#    'back together': 1,
#    'together the': 1,
#    'the top': 1,
#    'top seems': 1,
#    'seems fit': 1,
#    'fit little': 1,
#    'little tightly': 1,
#    'tightly use': 1,
#    'use tray': 1,
#    'tray side': 1,
#    'side without': 1,
#    'without making': 1,
#    'making huge': 1,
#    'huge effort': 1,
#    'effort pull': 1,
#    'pull two': 1,
#    'piece apart': 1,
#    'apart i': 1,
#    'i dont': 1,
#    'dont think': 1,
#    'think worth': 1,
#    'worth money': 1,
#    'money i': 1,
#    'i paid': 1,
#    'paid actually': 1,
#    'actually saw': 1,
#    'saw offered': 1,
#    'offered lower': 1,
#    'lower price': 1,
#    'price later': 1,
#    'later another': 1,
#    'another site': 1,
#    'it': 1,
#    'ok': 1,
#    'when': 1,
#    'i': 5,
#    'went': 1,
#    'assemble': 1,
#    'leg': 3,
#    'found': 1,
#    'two': 3,
#    'wide': 1,
#    'crack': 2,
#    'going': 1,
#    'entire': 1,
#    'side': 2,
#    'luckily': 1,
#    'could': 1,
#    'face': 1,
#    'inside': 1,
#    'sight': 1,
#    'decided': 1,
#    'send': 1,
#    'back': 2,
#    'thinking': 1,
#    'split': 1,
#    'piece': 2,
#    'superglue': 1,
#    'together': 1,
#    'the': 1,
#    'top': 1,
#    'seems': 1,
#    'fit': 1,
#    'little': 1,
#    'tightly': 1,
#    'use': 1,
#    'tray': 1,
#    'without': 1,
#    'making': 1,
#    'huge': 1,
#    'effort': 1,
#    'pull': 1,
#    'apart': 1,
#    'dont': 1,
#    'think': 1,
#    'worth': 1,
#    'money': 1,
#    'paid': 1,
#    'actually': 1,
#    'saw': 1,
#    'offered': 1,
#    'lower': 1,
#    'price': 1,
#    'later': 1,
#    'another': 1,
#    'site': 1},
#   'fake'),
#  ({'worst experience': 1,
#    'experience i': 1,
#    'i ever': 1,
#    'ever buying': 1,
#    'buying hp': 1,
#    'hp envy': 1,
#    'envy m6': 1,
#    'm6 laptop': 1,
#    'laptop sellerbr': 1,
#    'sellerbr system': 1,
#    'system labelled': 1,
#    'labelled ': 1,
#    ' used': 1,
#    'used ': 1,
#    ' good': 1,
#    'good i': 1,
#    'i received': 1,
#    'received i': 1,
#    'i discovered': 1,
#    'discovered 2': 1,
#    '2 usb': 1,
#    'usb port': 1,
#    'port damaged': 1,
#    'damaged finger': 1,
#    'finger print': 1,
#    'print device': 1,
#    'device working': 1,
#    'working factory': 1,
#    'factory installed': 1,
#    'installed window': 1,
#    'window wiped': 1,
#    'wiped replaced': 1,
#    'replaced useless': 1,
#    'useless window': 1,
#    'window 8': 1,
#    '8 o': 1,
#    'o 4': 1,
#    '4 indicator': 1,
#    'indicator light': 1,
#    'light light': 1,
#    'light system': 1,
#    'system system': 1,
#    'system obviously': 1,
#    'obviously opened': 1,
#    'opened sold': 1,
#    'sold mebr': 1,
#    'mebr i': 1,
#    'i urge': 1,
#    'urge amazon': 1,
#    'amazon buyer': 1,
#    'buyer stay': 1,
#    'stay away': 1,
#    'away seller': 1,
#    'seller he': 1,
#    'he cheated': 1,
#    'worst': 1,
#    'experience': 1,
#    'i': 4,
#    'ever': 1,
#    'buying': 1,
#    'hp': 1,
#    'envy': 1,
#    'm6': 1,
#    'laptop': 1,
# ...
#    'light': 1,
#    'weight': 1,
#    'plastic': 2,
#    'easy': 1,
#    'eat': 3,
#    'my': 1,
#    'girl': 1,
#    '11': 1,
#    'month': 1,
#    'old': 1,
#    'puppy': 1,
#    'able': 1,
#    '10': 1,
#    'minute': 1,
#    'hoping': 1,
#    'harder': 1,
#    'like': 1,
#    'normal': 1,
#    'kong': 1,
#    'toy': 1,
#    'if': 2,
#    'chewer': 2,
#    'dont': 1,
#    'waste': 1,
#    'moneybr': 1,
#    'br': 1,
#    'pup': 1,
#    'doesnt': 1,
#    'chew': 1,
#    'play': 1,
#    'would': 1,
#    'say': 1,
#    'go': 1,
#    'but': 1,
#    'short': 1,
#    'order': 1},
#   'fake'),
#  ({'time tell': 1,
#    'tell lot': 1,
#    'lot saw': 1,
#    'saw money': 1,
#    'money since': 1,
#    'since i': 1,
#    'i occasional': 1,
#    'occasional user': 1,
#    'user last': 1,
#    'last many': 1,
#    'many year': 1,
#    'time': 1,
#    'tell': 1,
#    'lot': 1,
#    'saw': 1,
#    'money': 1,
#    'since': 1,
#    'i': 1,
#    'occasional': 1,
#    'user': 1,
#    'last': 1,
#    'many': 1,
#    'year': 1},
#   'fake'),
#  ({'this first': 1,
#    'first time': 1,
#    'time trying': 1,
#    'trying feel': 1,
#    'feel easy': 1,
#    'easy use': 1,
#    'use tell': 1,
#    'tell u': 1,
#    'u turn': 1,
#    'turn got': 1,
#    'got heated': 1,
#    'heated enough': 1,
#    'enough get': 1,
#    'get started': 1,
#    'this': 1,
#    'first': 1,
#    'time': 1,
#    'trying': 1,
#    'feel': 1,
#    'easy': 1,
#    'use': 1,
#    'tell': 1,
#    'u': 1,
#    'turn': 1,
#    'got': 1,
#    'heated': 1,
#    'enough': 1,
#    'get': 1,
#    'started': 1},
#   'fake'),
#  ({'my husband': 1,
#    'husband ringdemon': 1,
#    'ringdemon gamer': 1,
#    'gamer absolutely': 1,
#    'absolutely love': 1,
#    'love chair': 1,
#    'chair he': 1,
#    'he say': 1,
#    'say 34great': 1,
#    '34great lumbar': 1,
#    'lumbar support': 1,
#    'support comfortable': 1,
#    'comfortable sit': 1,
#    'sit long': 1,
#    'long period': 1,
#    'period time': 1,
#    'time sound': 1,
#    'sound system': 1,
#    'system awesome': 1,
#    'my': 1,
#    'husband': 1,
#    'ringdemon': 1,
#    'gamer': 1,
#    'absolutely': 1,
#    'love': 1,
#    'chair': 1,
#    'he': 1,
#    'say': 1,
#    '34great': 1,
#    'lumbar': 1,
#    'support': 1,
#    'comfortable': 1,
#    'sit': 1,
#    'long': 1,
#    'period': 1,
#    'time': 1,
#    'sound': 1,
#    'system': 1,
#    'awesome': 1},
#   'fake'),
#  ({'this product': 1,
#    'product exactly': 1,
#    'exactly id': 1,
#    'id expected': 1,
#    'expected perfect': 1,
#    'perfect i': 1,
#    'i intended': 1,
#    'intended use': 1,
#    'use ': 1,
#    ' safely': 1,
#    'safely storing': 1,
#    'storing overwhelming': 1,
#    'overwhelming amount': 1,
#    'amount scarf': 1,
#    'scarf just': 1,
#    'just circle': 1,
#    'circle smooth': 1,
#    'smooth enough': 1,
#    'enough need': 1,
#    'need slowly': 1,
#    'slowly pull': 1,
#    'pull scarf': 1,
#    'scarf overall': 1,
#    'overall great': 1,
#    'great functional': 1,
#    'this': 1,
#    'product': 1,
#    'exactly': 1,
#    'id': 1,
#    'expected': 1,
#    'perfect': 1,
#    'i': 1,
#    'intended': 1,
#    'use': 1,
#    '': 1,
#    'safely': 1,
#    'storing': 1,
#    'overwhelming': 1,
#    'amount': 1,
#    'scarf': 2,
#    'just': 1,
#    'circle': 1,
#    'smooth': 1,
#    'enough': 1,
#    'need': 1,
#    'slowly': 1,
#    'pull': 1,
#    'overall': 1,
#    'great': 1,
#    'functional': 1},
#   'fake'),
#  ({'toast bread': 1,
#    'bread really': 1,
#    'really nice': 1,
#    'nice look': 1,
#    'look good': 1,
#    'good counter': 1,
#    'counter i': 1,
#    'i havent': 1,
#    'havent uneven': 1,
#    'uneven burn': 1,
#    'burn yet': 1,
#    'yet toaster': 1,
#    'toaster make': 1,
#    'make kitchen': 1,
#    'kitchen look': 1,
#    'look like': 1,
#    'like heavy': 1,
#    'heavy machinery': 1,
#    'machinery vibe': 1,
#    'toast': 1,
#    'bread': 1,
#    'really': 1,
#    'nice': 1,
#    'look': 2,
#    'good': 1,
#    'counter': 1,
#    'i': 1,
#    'havent': 1,
#    'uneven': 1,
#    'burn': 1,
#    'yet': 1,
#    'toaster': 1,
#    'make': 1,
#    'kitchen': 1,
#    'like': 1,
#    'heavy': 1,
#    'machinery': 1,
#    'vibe': 1},
#   'fake'),
#  ({'word cant': 1,
#    'cant describe': 1,
#    'describe much': 1,
#    'much i': 1,
#    'i love': 1,
#    'love coffee': 1,
#    'coffee maker': 2,
#    'maker i': 1,
#    'i gladly': 1,
#    'gladly pay': 1,
#    'pay extra': 1,
#    'extra couple': 1,
#    'couple dollar': 1,
#    'dollar kcups': 1,
#    'kcups bagged': 1,
#    'bagged coffee': 1,
#    'coffee convenience': 1,
#    'convenience ease': 1,
#    'ease machine': 1,
#    'machine it': 1,
#    'it make': 1,
#    'make delicious': 1,
#    'delicious hot': 1,
#    'hot coffee': 1,
#    'coffee 30': 1,
#    '30 second': 1,
#    'second you': 1,
#    'you leave': 1,
#    'leave coffee': 1,
#    'coffee pod': 1,
#    'pod empty': 1,
#    'empty make': 1,
#    'make hot': 1,
#    'hot cup': 1,
#    'cup water': 1,
#    'water tea': 1,
#    'tea ive': 1,
#    'ive also': 1,
#    'also used': 1,
#    'used product': 1,
#    'product warm': 1,
#    'warm baby': 1,
#    'baby bottle': 1,
#    'bottle instead': 1,
#    'instead boiling': 1,
#    'boiling water': 1,
#    'water ive': 1,
#    'ive used': 1,
#    'used keurig': 1,
#    'keurig least': 1,
#    'least 3': 1,
#    '3 time': 1,
#    'time day': 1,
#    'day 2': 1,
#    '2 year': 1,
#    'year havent': 1,
#    'havent one': 1,
#    'one problem': 1,
#    'problem yet': 1,
#    'yet the': 1,
#    'the price': 1,
#    'price high': 1,
#    'high coffee': 1,
#    'maker literally': 1,
#    'literally last': 1,
#    'last forever': 1,
#    'forever i': 1,
#    'i highly': 1,
#    'highly recommend': 1,
#    'recommend product': 1,
#    'word': 1,
#    'cant': 1,
#    'describe': 1,
#    'much': 1,
#    'i': 3,
#    'love': 1,
#    'coffee': 5,
#    'maker': 2,
#    'gladly': 1,
#    'pay': 1,
#    'extra': 1,
#    'couple': 1,
#    'dollar': 1,
#    'kcups': 1,
#    'bagged': 1,
#    'convenience': 1,
#    'ease': 1,
#    'machine': 1,
#    'it': 1,
#    'make': 2,
#    'delicious': 1,
#    'hot': 2,
#    '30': 1,
#    'second': 1,
#    'you': 1,
#    'leave': 1,
#    'pod': 1,
#    'empty': 1,
#    'cup': 1,
#    'water': 2,
#    'tea': 1,
#    'ive': 2,
#    'also': 1,
#    'used': 2,
#    'product': 2,
#    'warm': 1,
#    'baby': 1,
#    'bottle': 1,
#    'instead': 1,
#    'boiling': 1,
#    'keurig': 1,
#    'least': 1,
#    '3': 1,
#    'time': 1,
#    'day': 1,
#    '2': 1,
#    'year': 1,
#    'havent': 1,
#    'one': 1,
#    'problem': 1,
#    'yet': 1,
#    'the': 1,
#    'price': 1,
#    'high': 1,
#    'literally': 1,
#    'last': 1,
#    'forever': 1,
#    'highly': 1,
#    'recommend': 1},
#   'fake'),
#  ({'i got': 1,
#    'got protector': 1,
#    'protector afraid': 1,
#    'afraid bubble': 1,
#    'bubble i': 1,
#    'i placed': 1,
#    'placed i': 1,
#    'i noticed': 1,
#    'noticed got': 1,
#    'got smooth': 1,
#    'smooth not': 1,
#    'not single': 1,
#    'single bubble': 1,
#    'bubble left': 1,
#    'left perfect': 1,
#    'perfect fit': 1,
#    'i': 3,
#    'got': 2,
#    'protector': 1,
#    'afraid': 1,
#    'bubble': 2,
#    'placed': 1,
#    'noticed': 1,
#    'smooth': 1,
#    'not': 1,
#    'single': 1,
#    'left': 1,
#    'perfect': 1,
#    'fit': 1},
#   'fake'),
#  ({'nice wood': 1,
#    'wood block': 1,
#    'block smaller': 1,
#    'smaller i': 1,
#    'i thought': 1,
#    'thought would': 1,
#    'would my': 1,
#    'my son': 1,
#    'son love': 1,
#    'love stack': 1,
#    'stack ': 1,
#    ' build': 1,
#    'build tho': 1,
#    'nice': 1,
#    'wood': 1,
#    'block': 1,
#    'smaller': 1,
#    'i': 1,
#    'thought': 1,
#    'would': 1,
#    'my': 1,
#    'son': 1,
#    'love': 1,
#    'stack': 1,
#    '': 1,
#    'build': 1,
#    'tho': 1},
#   'fake'),
#  ({'the new': 1,
#    'new longer': 1,
#    'longer lasting': 1,
#    'lasting scent': 1,
#    'scent smell': 1,
#    'smell nothing': 1,
#    'nothing like': 1,
#    'like old': 1,
#    'old original': 1,
#    'original i': 1,
#    'i longer': 1,
#    'longer purchase': 1,
#    'purchase product': 1,
#    'product the': 1,
#    'the cleaning': 1,
#    'cleaning ability': 1,
#    'ability yes': 1,
#    'yes i': 1,
#    'i like': 1,
#    'like new': 1,
#    'new improved': 1,
#    'improved scent': 1,
#    'the': 2,
#    'new': 2,
#    'longer': 2,
#    'lasting': 1,
#    'scent': 2,
#    'smell': 1,
#    'nothing': 1,
#    'like': 2,
#    'old': 1,
#    'original': 1,
#    'i': 2,
#    'purchase': 1,
#    'product': 1,
#    'cleaning': 1,
#    'ability': 1,
#    'yes': 1,
#    'improved': 1},
#   'fake'),
#  ({'winter glove': 1,
#    'glove actually': 1,
#    'actually great': 1,
#    'great affordable': 1,
#    'affordable reliable': 1,
#    'reliable cloth': 1,
#    'cloth afraid': 1,
#    'afraid texture': 1,
#    'texture might': 1,
#    'might cause': 1,
#    'cause skin': 1,
#    'skin allergy': 1,
#    'allergy thankfully': 1,
#    'thankfully allergy': 1,
#    'allergy using': 1,
#    'using glovesbr': 1,
#    'glovesbr br': 1,
#    'br didnt': 1,
#    'didnt know': 1,
#    'know spend': 1,
#    'spend last': 1,
#    'last 250': 1,
#    '250 dollar': 1,
#    'dollar purchased': 1,
#    'purchased little': 1,
#    'little know': 1,
#    'know buying': 1,
#    'buying worth': 1,
#    'winter': 1,
#    'glove': 1,
#    'actually': 1,
#    'great': 1,
#    'affordable': 1,
#    'reliable': 1,
#    'cloth': 1,
#    'afraid': 1,
#    'texture': 1,
#    'might': 1,
#    'cause': 1,
#    'skin': 1,
#    'allergy': 2,
#    'thankfully': 1,
#    'using': 1,
#    'glovesbr': 1,
#    'br': 1,
#    'didnt': 1,
#    'know': 2,
#    'spend': 1,
#    'last': 1,
#    '250': 1,
#    'dollar': 1,
#    'purchased': 1,
#    'little': 1,
#    'buying': 1,
#    'worth': 1},
#   'fake'),
#  ({'this kind': 1,
#    'kind silly': 1,
#    'silly true': 1,
#    'true time': 1,
#    'time basically': 1,
#    'basically want': 1,
#    'want something': 1,
#    'something point': 1,
#    'point direction': 1,
#    'direction get': 1,
#    'get simple': 1,
#    'simple enough': 1,
#    'enough go': 1,
#    'go the': 1,
#    'the book': 1,
#    'book summarized': 1,
#    'summarized condensed': 1,
#    'condensed maxim': 1,
#    'maxim go': 1,
#    'this': 1,
#    'kind': 1,
#    'silly': 1,
#    'true': 1,
#    'time': 1,
#    'basically': 1,
#    'want': 1,
#    'something': 1,
#    'point': 1,
#    'direction': 1,
#    'get': 1,
#    'simple': 1,
#    'enough': 1,
#    'go': 2,
#    'the': 1,
#    'book': 1,
#    'summarized': 1,
#    'condensed': 1,
#    'maxim': 1},
#   'fake'),
#  ({'i happy': 1,
#    'happy unit': 1,
#    'unit error': 1,
#    'error message': 1,
#    'message often': 1,
#    'often course': 1,
#    'course warranty': 1,
#    'warranty seller': 1,
#    'seller china': 1,
#    'i': 1,
#    'happy': 1,
#    'unit': 1,
#    'error': 1,
#    'message': 1,
#    'often': 1,
#    'course': 1,
#    'warranty': 1,
#    'seller': 1,
#    'china': 1},
#   'fake'),
#  ({'i used': 1,
#    'used product': 1,
#    'product year': 1,
#    'year great': 1,
#    'great success': 1,
#    'success family': 1,
#    'family european': 1,
#    'european car': 1,
#    'car motorcycle': 1,
#    'motorcycle lawn': 1,
#    'lawn outdoor': 1,
#    'outdoor equipment': 1,
#    'equipment they': 1,
#    'they best': 1,
#    'best price': 1,
#    'price often': 1,
#    'often stock': 1,
#    'stock area': 1,
#    'i': 1,
#    'used': 1,
#    'product': 1,
#    'year': 1,
#    'great': 1,
#    'success': 1,
#    'family': 1,
#    'european': 1,
#    'car': 1,
#    'motorcycle': 1,
#    'lawn': 1,
#    'outdoor': 1,
#    'equipment': 1,
#    'they': 1,
#    'best': 1,
#    'price': 1,
#    'often': 1,
#    'stock': 1,
#    'area': 1},
#   'fake'),
#  ({'very negative': 1,
#    'negative machine': 1,
#    'machine i': 1,
#    'i enjoyed': 1,
#    'enjoyed family': 1,
#    'family i': 1,
#    'i feel': 1,
#    'feel bad': 1,
#    'bad spend': 1,
#    'spend money': 1,
#    'money the': 1,
#    'the overall': 1,
#    'overall sound': 1,
#    'sound quality': 1,
#    'quality good': 1,
#    'good easy': 1,
#    'easy set': 1,
#    'set den': 1,
#    'very': 1,
#    'negative': 1,
#    'machine': 1,
#    'i': 2,
#    'enjoyed': 1,
#    'family': 1,
#    'feel': 1,
#    'bad': 1,
#    'spend': 1,
#    'money': 1,
#    'the': 1,
#    'overall': 1,
#    'sound': 1,
#    'quality': 1,
#    'good': 1,
#    'easy': 1,
#    'set': 1,
#    'den': 1},
#   'fake'),
#  ({'the product': 1,
#    'product actually': 1,
#    'actually helped': 1,
#    'helped lot': 1,
#    'lot area': 1,
#    'area particularly': 1,
#    'particularly workout': 1,
#    'workout performance': 1,
#    'performance concerned': 1,
#    'concerned but': 1,
#    'but i': 1,
#    'i expecting': 1,
#    'expecting burn': 1,
#    'burn fat': 1,
#    'fat maybe': 1,
#    'maybe research': 1,
#    'research wrong': 1,
#    'the': 1,
#    'product': 1,
#    'actually': 1,
#    'helped': 1,
#    'lot': 1,
#    'area': 1,
#    'particularly': 1,
#    'workout': 1,
#    'performance': 1,
#    'concerned': 1,
#    'but': 1,
#    'i': 1,
#    'expecting': 1,
#    'burn': 1,
#    'fat': 1,
#    'maybe': 1,
#    'research': 1,
#    'wrong': 1},
#   'fake'),
#  ({'good sound': 1,
#    'sound best': 1,
#    'best quality': 1,
#    'quality ': 1,
#    ' nice': 1,
#    'nice celerity': 1,
#    'celerity nice': 1,
#    'nice looking': 1,
#    'looking body': 1,
#    'body super': 1,
#    'super awesome': 1,
#    'awesome product': 1,
#    'product best': 1,
#    'best thing': 1,
#    'thing loud': 1,
#    'loud voice': 1,
#    'good': 1,
#    'sound': 1,
#    'best': 2,
#    'quality': 1,
#    '': 1,
#    'nice': 2,
#    'celerity': 1,
#    'looking': 1,
#    'body': 1,
#    'super': 1,
#    'awesome': 1,
#    'product': 1,
#    'thing': 1,
#    'loud': 1,
#    'voice': 1},
#   'fake'),
#  ({'like minimalist': 1,
#    'minimalist stand': 1,
#    'stand doesnt': 1,
#    'doesnt take': 1,
#    'take much': 1,
#    'much space': 1,
#    'space look': 1,
#    'look classy': 1,
#    'classy well': 1,
#    'well one': 1,
#    'one thing': 1,
#    'thing hate': 1,
#    'hate though': 1,
#    'though difficult': 1,
#    'difficult adjust': 1,
#    'adjust inclination': 1,
#    'inclination stand': 1,
#    'stand self': 1,
#    'self doesnt': 1,
#    'doesnt hold': 1,
#    'hold especially': 1,
#    'especially glass': 1,
#    'glass table': 1,
#    'like': 1,
#    'minimalist': 1,
#    'stand': 2,
#    'doesnt': 2,
#    'take': 1,
#    'much': 1,
#    'space': 1,
#    'look': 1,
#    'classy': 1,
#    'well': 1,
#    'one': 1,
#    'thing': 1,
#    'hate': 1,
#    'though': 1,
#    'difficult': 1,
#    'adjust': 1,
#    'inclination': 1,
#    'self': 1,
#    'hold': 1,
#    'especially': 1,
#    'glass': 1,
#    'table': 1},
#   'fake'),
#  ({'i kit': 1,
#    'kit couple': 1,
#    'couple year': 1,
#    'year dremel': 1,
#    'dremel mean': 1,
#    'mean quality': 1,
#    'quality ok': 1,
#    'ok price': 1,
#    'price amazing': 1,
#    'amazing basically': 1,
#    'basically get': 1,
#    'get pay': 1,
#    'pay got': 1,
#    'got little': 1,
#    'little bit': 1,
#    'bit everything': 1,
#    'everything comprehensive': 1,
#    'comprehensive great': 1,
#    'great starter': 1,
#    'starter kit': 1,
#    'kit beginner': 1,
#    'beginner i': 1,
#    'i highly': 1,
#    'highly recommend': 1,
#    'recommend someone': 1,
#    'someone starting': 1,
#    'starting outbr': 1,
#    'outbr br': 1,
#    'br i': 1,
#    'i gave': 1,
#    'gave 3': 1,
#    '3 star': 1,
#    'star rating': 1,
#    'rating little': 1,
#    'little cheap': 1,
#    'cheap side': 1,
#    'side money': 1,
#    'money well': 1,
#    'well worth': 1,
#    'worth i': 1,
#    'i going': 1,
#    'going buy': 1,
#    'buy i': 1,
#    'i would': 1,
#    'would 500pc': 1,
#    '500pc set': 1,
#    'set i': 1,
#    'i linked': 1,
#    'linked ive': 1,
#    'ive seen': 1,
#    'seen friend': 1,
#    'friend place': 1,
#    'place comprehensive': 1,
#    'comprehensive surprisingly': 1,
#    'surprisingly good': 1,
#    'good quality': 1,
#    'quality look': 1,
#    'look kick': 1,
#    'kick asinb00cvzslr6': 1,
#    'asinb00cvzslr6 500pc': 1,
#    '500pc rotary': 1,
#    'rotary tool': 1,
#    'tool accessory': 1,
#    'accessory set': 1,
#    'set kit': 1,
#    'kit bit': 1,
#    'bit fit': 1,
#    'fit dremel': 1,
#    'dremel cutting': 1,
#    'cutting grinding': 1,
#    'grinding sanding': 1,
#    'sanding polishing': 1,
#    'i': 6,
#    'kit': 3,
#    'couple': 1,
#    'year': 1,
#    'dremel': 2,
#    'mean': 1,
#    'quality': 2,
#    'ok': 1,
#    'price': 1,
#    'amazing': 1,
#    'basically': 1,
#    'get': 1,
#    'pay': 1,
#    'got': 1,
#    'little': 2,
#    'bit': 2,
#    'everything': 1,
#    'comprehensive': 2,
#    'great': 1,
#    'starter': 1,
#    'beginner': 1,
#    'highly': 1,
#    'recommend': 1,
#    'someone': 1,
#    'starting': 1,
#    'outbr': 1,
#    'br': 1,
#    'gave': 1,
#    '3': 1,
#    'star': 1,
#    'rating': 1,
#    'cheap': 1,
#    'side': 1,
#    'money': 1,
#    'well': 1,
#    'worth': 1,
#    'going': 1,
#    'buy': 1,
#    'would': 1,
#    '500pc': 2,
#    'set': 2,
#    'linked': 1,
#    'ive': 1,
#    'seen': 1,
#    'friend': 1,
#    'place': 1,
#    'surprisingly': 1,
#    'good': 1,
#    'look': 1,
#    'kick': 1,
#    'asinb00cvzslr6': 1,
#    'rotary': 1,
#    'tool': 1,
#    'accessory': 1,
#    'fit': 1,
#    'cutting': 1,
#    'grinding': 1,
#    'sanding': 1,
#    'polishing': 1},
#   'fake'),
#  ...]

# %%
print(crossValidate(trainData,10))
# Out:
# [0.84762434 0.84339546 0.76092619 0.78478932]

# %%
print(crossValidate(testData,10))
# Out:
# [0.76135057 0.76096499 0.72104962 0.72982577]

# %%
classifier=trainClassifierlassifier(trainData)

# %%
classifier
# Out:
# <SklearnClassifier(Pipeline(memory=None,
#          steps=[('svc',
#                  LinearSVC(C=0.01, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='squared_hinge', max_iter=1000,
#                            multi_class='ovr', penalty='l2', random_state=None,
#                            tol=0.0001, verbose=0))],
#          verbose=False))>

# %%
import pickle

# %%
pickle.dump(classifier,open('classifier.sav','wb'))
