# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df= pd.read_csv('cwurData.csv')

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 3          50   86.17  2012
# 4          18   85.21  2012
# ...       ...     ...   ...
# 2195      816   44.03  2015
# 2196      871   44.03  2015
# 2197      824   44.03  2015
# 2198      651   44.02  2015
# 2199      547   44.02  2015
#
# [2200 rows x 14 columns]

# %%
df['year'].value_counts()
# Out:
# 2015    1000
# 2014    1000
# 2013     100
# 2012     100
# Name: year, dtype: int64

# %%
df2012= df[df['year']==2012]
df2013= df[df['year']==2013]
df2014= df[df['year']==2014]
df2015= df[df['year']==2015]

# %%
df2012.drop('year',axis=1,inplace=True)
df2013.drop('year',axis=1,inplace=True)
df2014.drop('year',axis=1,inplace=True)
df2015.drop('year',axis=1,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df2012.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score
# 0             1          1          1           NaN        5  100.00
# 1            12          4          4           NaN        1   91.67
# 2             4          2          2           NaN       15   89.50
# 3            16         16         11           NaN       50   86.17
# 4            37         22         22           NaN       18   85.21

# %%
df2013.head()
# Out:
#      world_rank                            institution         country  \
# 100           1                     Harvard University             USA
# 101           2                    Stanford University             USA
# 102           3                   University of Oxford  United Kingdom
# 103           4  Massachusetts Institute of Technology             USA
# 104           5                University of Cambridge  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 100              1                     1                  1
# 101              2                    11                  2
# 102              1                     7                 12
# 103              3                     2                 16
# 104              2                     3                 15
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 100                   1             1          1          1           NaN
# 101                   4             6          2          2           NaN
# 102                  10            11          7         13           NaN
# 103                   2            16          3          3           NaN
# 104                   5             9         11         10           NaN
#
#      patents   score
# 100        7  100.00
# 101       11   93.94
# 102       15   92.54
# 103        1   91.45
# 104       39   90.24

# %%
df2014.head()
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# 202              3                     3                 11
# 203              1                     2                 10
# 204              2                     7                 12
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 200                   1             1          1          1           1.0
# 201                   4             5          3          3           4.0
# 202                   2            15          2          2           2.0
# 203                   5            10          9         12          13.0
# 204                  10            11         12         11          12.0
#
#      patents   score
# 200        2  100.00
# 201        6   99.09
# 202        1   98.69
# 203       48   97.64
# 204       16   97.51

# %%
df2015.head()
# Out:
#       world_rank                            institution         country  \
# 1200           1                     Harvard University             USA
# 1201           2                    Stanford University             USA
# 1202           3  Massachusetts Institute of Technology             USA
# 1203           4                University of Cambridge  United Kingdom
# 1204           5                   University of Oxford  United Kingdom
#
#       national_rank  quality_of_education  alumni_employment  \
# 1200              1                     1                  1
# 1201              2                     9                  2
# 1202              3                     3                 11
# 1203              1                     2                 10
# 1204              2                     7                 13
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1200                   1             1          1          1           1.0
# 1201                   4             5          3          3           4.0
# 1202                   2            15          2          2           2.0
# 1203                   5            11          6         12          13.0
# 1204                  10             7         12          7           9.0
#
#       patents   score
# 1200        3  100.00
# 1201       10   98.66
# 1202        1   97.54
# 1203       48   96.81
# 1204       15   96.46

# %%
df2015.corr()
# Out:
#                       world_rank  national_rank  quality_of_education  \
# world_rank              1.000000       0.207617              0.577612
# national_rank           0.207617       1.000000              0.170368
# quality_of_education    0.577612       0.170368              1.000000
# alumni_employment       0.586218       0.078447              0.473653
# quality_of_faculty      0.572304       0.171665              0.685989
# publications            0.907588       0.303851              0.521378
# influence               0.876108       0.123909              0.549574
# citations               0.823055       0.158244              0.521067
# broad_impact            0.947204       0.181568              0.517966
# patents                 0.639701       0.104223              0.386652
# score                  -0.554571      -0.176447             -0.595771
#
#                       alumni_employment  quality_of_faculty  publications  \
# world_rank                     0.586218            0.572304      0.907588
# national_rank                  0.078447            0.171665      0.303851
# quality_of_education           0.473653            0.685989      0.521378
# alumni_employment              1.000000            0.390605      0.476797
# quality_of_faculty             0.390605            1.000000      0.537166
# publications                   0.476797            0.537166      1.000000
# influence                      0.418218            0.570487      0.845110
# citations                      0.449119            0.559989      0.788885
# broad_impact                   0.428065            0.553277      0.918436
# patents                        0.398035            0.418088      0.616911
# score                         -0.480756           -0.708048     -0.521738
#
#                       influence  citations  broad_impact   patents     score
# world_rank             0.876108   0.823055      0.947204  0.639701 -0.554571
# national_rank          0.123909   0.158244      0.181568  0.104223 -0.176447
# quality_of_education   0.549574   0.521067      0.517966  0.386652 -0.595771
# alumni_employment      0.418218   0.449119      0.428065  0.398035 -0.480756
# quality_of_faculty     0.570487   0.559989      0.553277  0.418088 -0.708048
# publications           0.845110   0.788885      0.918436  0.616911 -0.521738
# influence              1.000000   0.808917      0.913889  0.548654 -0.522732
# citations              0.808917   1.000000      0.850637  0.518144 -0.517301
# broad_impact           0.913889   0.850637      1.000000  0.580644 -0.527617
# patents                0.548654   0.518144      0.580644  1.000000 -0.454706
# score                 -0.522732  -0.517301     -0.527617 -0.454706  1.000000

# %%
sns.lmplot(x='score',y='world_rank',data=df2015)

# %%
sns.jointplot(x='score',y='quality_of_education',data=df2015)

# %%
plt.figure(figsize=(12,6))
df2015new= df2015.set_index(keys=df2015['institution'])
fig= sns.heatmap(df2015new.drop(['institution','country'],axis=1),cmap='coolwarm')
plt.tight_layout()

# %%
df2015high= df2015[df2015['score']>60]
df2015high
# Out:
#       world_rank                                      institution  \
# 1200           1                               Harvard University
# 1201           2                              Stanford University
# 1202           3            Massachusetts Institute of Technology
# 1203           4                          University of Cambridge
# 1204           5                             University of Oxford
# 1205           6                              Columbia University
# 1206           7               University of California, Berkeley
# 1207           8                            University of Chicago
# 1208           9                             Princeton University
# 1209          10                               Cornell University
# 1210          11                                  Yale University
# 1211          12               California Institute of Technology
# 1212          13                              University of Tokyo
# 1213          14                       University of Pennsylvania
# 1214          15            University of California, Los Angeles
# 1215          16                         Johns Hopkins University
# 1216          17                                 Kyoto University
# 1217          18                              New York University
# 1218          19                University of Michigan, Ann Arbor
# 1219          20  Swiss Federal Institute of Technology in Zurich
# 1220          21              University of California, San Diego
# 1221          22                          Northwestern University
# 1222          23                   Hebrew University of Jerusalem
# 1223          24                        Seoul National University
# 1224          25                  University of Wisconsin–Madison
# 1225          26          University of California, San Francisco
# 1226          27                        University College London
# 1227          28                                  Duke University
# 1228          29                           Rockefeller University
# 1229          30                    University of Texas at Austin
# 1230          31               University of Washington - Seattle
# 1231          32                            University of Toronto
#
#              country  national_rank  quality_of_education  alumni_employment  \
# 1200             USA              1                     1                  1
# 1201             USA              2                     9                  2
# 1202             USA              3                     3                 11
# 1203  United Kingdom              1                     2                 10
# 1204  United Kingdom              2                     7                 13
# 1205             USA              4                    13                  6
# 1206             USA              5                     5                 21
# 1207             USA              6                    11                 14
# 1208             USA              7                     4                 15
# 1209             USA              8                    12                 18
# 1210             USA              9                    10                 26
# 1211             USA             10                     6                328
# 1212           Japan              1                    16                  3
# 1213             USA             11                    20                  4
# 1214             USA             12                    28                 27
# 1215             USA             13                    18                 84
# 1216           Japan              2                    22                 16
# 1217             USA             14                    32                 22
# 1218             USA             15                    24                 17
# 1219     Switzerland              1                    17                 64
# 1220             USA             16                    36                567
# 1221             USA             17                   163                 12
# 1222          Israel              1                    15                164
# 1223     South Korea              1                   367                  9
# 1224             USA             18                    29                 29
# 1225             USA             19                   367                567
# 1226  United Kingdom              3                    21                447
# 1227             USA             20                    74                 31
# 1228             USA             21                    49                567
# 1229             USA             22                    75                 36
# 1230             USA             23                    48                103
# 1231          Canada              1                    70                 51
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 1200                   1             1          1          1           1.0
# 1201                   4             5          3          3           4.0
# 1202                   2            15          2          2           2.0
# 1203                   5            11          6         12          13.0
# 1204                  10             7         12          7           9.0
# 1205                   9            13         13         11          12.0
# 1206                   6            10          4          4           7.0
# 1207                   8            17         16         12          22.0
# 1208                   3            72         25         24          33.0
# 1209                  14            24         15         25          22.0
# 1210                  11            18          8         35          20.0
# 1211                   7            53          9         19          25.0
# 1212                  38            14         19         31          29.0
# 1213                  28             8         18         14           9.0
# 1214                  13             6         14          8           6.0
# 1215                  16             4         11          5           3.0
# 1216                  24            30         42         88          60.0
# 1217                  18            47         29         46          32.0
# 1218                 140             3         20          6          14.0
# 1219                  17            44         27         39          79.0
# 1220                  19            16          5         15          15.0
# 1221                 104            27         34         27          26.0
# 1222                  15           120         97        368         143.0
# 1223                 218            36        163        146         112.0
# 1224                  34            21         24         22          27.0
# 1225                  20            22          7         15          11.0
# 1226                  27            12         22         15          18.0
# 1227                  56            19         23         15          16.0
# 1228                  12           372         28        115          70.0
# 1229                  25            48         50         26          71.0
# 1230                  41             9         10         10           5.0
# 1231                  32             2         17          9           8.0
#
#       patents   score
# 1200        3  100.00
# 1201       10   98.66
# 1202        1   97.54
# 1203       48   96.81
# 1204       15   96.46
# 1205        4   96.14
# 1206       29   92.25
# 1207      141   90.70
# 1208      225   89.42
# 1209       11   86.79
# 1210       49   86.61
# 1211       13   84.40
# 1212        7   78.23
# 1213       14   77.60
# 1214        9   76.91
# 1215        2   71.60
# 1216       16   68.60
# 1217       43   68.39
# 1218       12   68.36
# 1219       57   66.93
# 1220       17   66.59
# 1221       42   66.56
# 1222       35   65.71
# 1223        6   64.82
# 1224       27   64.51
# 1225       56   63.69
# 1226       67   62.27
# 1227       33   61.55
# 1228      289   61.28
# 1229       38   61.14
# 1230       40   60.61
# 1231      145   60.04

# %%
plt.hist(df2015high['country'],bins=30)
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split

# %%
X= df2015.drop(['institution','country','world_rank','score'],axis=1)
y= df2015['score']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm= LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred= lm.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test,pred))
# Out:
# 1.8937038460574556
